# %% [markdown]
#  # OUTTA AI 부트캠프 팀 프로젝트 실습 : GAN

# %% [markdown]
# <h4><div style="text-align: right"> Last Edit: Aug 04, 2023. </div> <br>

# %% [markdown]
# > ## 구글 드라이브를 연결하자.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# > ## 그 후, 다음의 코드를 실행하여 실습에 사용할 데이터셋의 압축을 풀도록 하자.

# %%
# !cp /content/drive/MyDrive/Classroom/advanced/6/GAN_dataset.zip /content/
# !unzip "/content/GAN_dataset.zip"
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: celebA/img/197605.jpg
#   inflating: celebA/img/197606.jpg
#   inflating: celebA/img/197607.jpg
#   inflating: celebA/img/197608.jpg
#   inflating: celebA/img/197609.jpg
#   inflating: celebA/img/197610.jpg
#   inflating: celebA/img/197611.jpg
#   inflating: celebA/img/197612.jpg
#   inflating: celebA/img/197613.jpg
#   inflating: celebA/img/197614.jpg
#   inflating: celebA/img/197615.jpg
#   inflating: celebA/img/197616.jpg
#   inflating: celebA/img/197617.jpg
#   inflating: celebA/img/197618.jpg
#   inflating: celebA/img/197619.jpg
#   inflating: celebA/img/197620.jpg
#   inflating: celebA/img/197621.jpg
#   inflating: celebA/img/197622.jpg
#   inflating: celebA/img/197623.jpg
#   inflating: celebA/img/197624.jpg
#   inflating: celebA/img/197625.jpg
#   inflating: celebA/img/197626.jpg
#   inflating: celebA/img/197627.jpg
#   inflating: celebA/img/197628.jpg
#   inflating: celebA/img/197629.jpg
#   inflating: celebA/img/197630.jpg
#   inflating: celebA/img/197631.jpg
#   inflating: celebA/img/197632.jpg
#   inflating: celebA/img/197633.jpg
#   inflating: celebA/img/197634.jpg
#   inflating: celebA/img/197635.jpg
#   inflating: celebA/img/197636.jpg
#   inflating: celebA/img/197637.jpg
#   inflating: celebA/img/197638.jpg
#   inflating: celebA/img/197639.jpg
#   inflating: celebA/img/197640.jpg
#   inflating: celebA/img/197641.jpg
#   inflating: celebA/img/197642.jpg
#   inflating: celebA/img/197643.jpg
#   inflating: celebA/img/197644.jpg
#   inflating: celebA/img/197645.jpg
#   inflating: celebA/img/197646.jpg
#   inflating: celebA/img/197647.jpg
#   inflating: celebA/img/197648.jpg
#   inflating: celebA/img/197649.jpg
#   inflating: celebA/img/197650.jpg
#   inflating: celebA/img/197651.jpg
#   inflating: celebA/img/197652.jpg
#   inflating: celebA/img/197653.jpg
#   inflating: celebA/img/197654.jpg
#   inflating: celebA/img/197655.jpg
#   inflating: celebA/img/197656.jpg
#   inflating: celebA/img/197657.jpg
#   inflating: celebA/img/197658.jpg
#   inflating: celebA/img/197659.jpg
#   inflating: celebA/img/197660.jpg
#   inflating: celebA/img/197661.jpg
#   inflating: celebA/img/197662.jpg
#   inflating: celebA/img/197663.jpg
#   inflating: celebA/img/197664.jpg
#   inflating: celebA/img/197665.jpg
#   inflating: celebA/img/197666.jpg
#   inflating: celebA/img/197667.jpg
#   inflating: celebA/img/197668.jpg
#   inflating: celebA/img/197669.jpg
#   inflating: celebA/img/197670.jpg
#   inflating: celebA/img/197671.jpg
#   inflating: celebA/img/197672.jpg
#   inflating: celebA/img/197673.jpg
#   inflating: celebA/img/197674.jpg
#   inflating: celebA/img/197675.jpg
#   inflating: celebA/img/197676.jpg
#   inflating: celebA/img/197677.jpg
#   inflating: celebA/img/197678.jpg
#   inflating: celebA/img/197679.jpg
#   inflating: celebA/img/197680.jpg
#   inflating: celebA/img/197681.jpg
#   inflating: celebA/img/197682.jpg
#   inflating: celebA/img/197683.jpg
#   inflating: celebA/img/197684.jpg
#   inflating: celebA/img/197685.jpg
#   inflating: celebA/img/197686.jpg
#   inflating: celebA/img/197687.jpg
#   inflating: celebA/img/197688.jpg
#   inflating: celebA/img/197689.jpg
#   inflating: celebA/img/197690.jpg
#   inflating: celebA/img/197691.jpg
#   inflating: celebA/img/197692.jpg
#   inflating: celebA/img/197693.jpg
#   inflating: celebA/img/197694.jpg
#   inflating: celebA/img/197695.jpg
#   inflating: celebA/img/197696.jpg
#   inflating: celebA/img/197697.jpg
#   inflating: celebA/img/197698.jpg
#   inflating: celebA/img/197699.jpg
#   inflating: celebA/img/197700.jpg
#   inflating: celebA/img/197701.jpg
#   inflating: celebA/img/197702.jpg
#   inflating: celebA/img/197703.jpg
#   inflating: celebA/img/197704.jpg
#   inflating: celebA/img/197705.jpg
#   inflating: celebA/img/197706.jpg
#   inflating: celebA/img/197707.jpg
#   inflating: celebA/img/197708.jpg
#   inflating: celebA/img/197709.jpg
#   inflating: celebA/img/197710.jpg
#   inflating: celebA/img/197711.jpg
#   inflating: celebA/img/197712.jpg
#   inflating: celebA/img/197713.jpg
#   inflating: celebA/img/197714.jpg
#   inflating: celebA/img/197715.jpg
#   inflating: celebA/img/197716.jpg
#   inflating: celebA/img/197717.jpg
#   inflating: celebA/img/197718.jpg
#   inflating: celebA/img/197719.jpg
#   inflating: celebA/img/197720.jpg
#   inflating: celebA/img/197721.jpg
#   inflating: celebA/img/197722.jpg
#   inflating: celebA/img/197723.jpg
#   inflating: celebA/img/197724.jpg
#   inflating: celebA/img/197725.jpg
#   inflating: celebA/img/197726.jpg
#   inflating: celebA/img/197727.jpg
#   inflating: celebA/img/197728.jpg
#   inflating: celebA/img/197729.jpg
#   inflating: celebA/img/197730.jpg
#   inflating: celebA/img/197731.jpg
#   inflating: celebA/img/197732.jpg
#   inflating: celebA/img/197733.jpg
#   inflating: celebA/img/197734.jpg
#   inflating: celebA/img/197735.jpg
#   inflating: celebA/img/197736.jpg
#   inflating: celebA/img/197737.jpg
#   inflating: celebA/img/197738.jpg
#   inflating: celebA/img/197739.jpg
#   inflating: celebA/img/197740.jpg
#   inflating: celebA/img/197741.jpg
#   inflating: celebA/img/197742.jpg
#   inflating: celebA/img/197743.jpg
#   inflating: celebA/img/197744.jpg
#   inflating: celebA/img/197745.jpg
#   inflating: celebA/img/197746.jpg
#   inflating: celebA/img/197747.jpg
#   inflating: celebA/img/197748.jpg
#   inflating: celebA/img/197749.jpg
#   inflating: celebA/img/197750.jpg
#   inflating: celebA/img/197751.jpg
#   inflating: celebA/img/197752.jpg
#   inflating: celebA/img/197753.jpg
#   inflating: celebA/img/197754.jpg
#   inflating: celebA/img/197755.jpg
#   inflating: celebA/img/197756.jpg
#   inflating: celebA/img/197757.jpg
#   inflating: celebA/img/197758.jpg
#   inflating: celebA/img/197759.jpg
#   inflating: celebA/img/197760.jpg
#   inflating: celebA/img/197761.jpg
#   inflating: celebA/img/197762.jpg
#   inflating: celebA/img/197763.jpg
#   inflating: celebA/img/197764.jpg
#   inflating: celebA/img/197765.jpg
#   inflating: celebA/img/197766.jpg
#   inflating: celebA/img/197767.jpg
#   inflating: celebA/img/197768.jpg
#   inflating: celebA/img/197769.jpg
#   inflating: celebA/img/197770.jpg
#   inflating: celebA/img/197771.jpg
#   inflating: celebA/img/197772.jpg
#   inflating: celebA/img/197773.jpg
#   inflating: celebA/img/197774.jpg
#   inflating: celebA/img/197775.jpg
#   inflating: celebA/img/197776.jpg
#   inflating: celebA/img/197777.jpg
#   inflating: celebA/img/197778.jpg
#   inflating: celebA/img/197779.jpg
#   inflating: celebA/img/197780.jpg
#   inflating: celebA/img/197781.jpg
#   inflating: celebA/img/197782.jpg
#   inflating: celebA/img/197783.jpg
#   inflating: celebA/img/197784.jpg
#   inflating: celebA/img/197785.jpg
#   inflating: celebA/img/197786.jpg
#   inflating: celebA/img/197787.jpg
#   inflating: celebA/img/197788.jpg
#   inflating: celebA/img/197789.jpg
#   inflating: celebA/img/197790.jpg
#   inflating: celebA/img/197791.jpg
#   inflating: celebA/img/197792.jpg
#   inflating: celebA/img/197793.jpg
#   inflating: celebA/img/197794.jpg
#   inflating: celebA/img/197795.jpg
#   inflating: celebA/img/197796.jpg
#   inflating: celebA/img/197797.jpg
#   inflating: celebA/img/197798.jpg
#   inflating: celebA/img/197799.jpg
#   inflating: celebA/img/197800.jpg
#   inflating: celebA/img/197801.jpg
#   inflating: celebA/img/197802.jpg
#   inflating: celebA/img/197803.jpg
#   inflating: celebA/img/197804.jpg
#   inflating: celebA/img/197805.jpg
#   inflating: celebA/img/197806.jpg
#   inflating: celebA/img/197807.jpg
#   inflating: celebA/img/197808.jpg
#   inflating: celebA/img/197809.jpg
#   inflating: celebA/img/197810.jpg
#   inflating: celebA/img/197811.jpg
#   inflating: celebA/img/197812.jpg
#   inflating: celebA/img/197813.jpg
#   inflating: celebA/img/197814.jpg
#   inflating: celebA/img/197815.jpg
#   inflating: celebA/img/197816.jpg
#   inflating: celebA/img/197817.jpg
#   inflating: celebA/img/197818.jpg
#   inflating: celebA/img/197819.jpg
#   inflating: celebA/img/197820.jpg
#   inflating: celebA/img/197821.jpg
#   inflating: celebA/img/197822.jpg
#   inflating: celebA/img/197823.jpg
#   inflating: celebA/img/197824.jpg
#   inflating: celebA/img/197825.jpg
#   inflating: celebA/img/197826.jpg
#   inflating: celebA/img/197827.jpg
#   inflating: celebA/img/197828.jpg
#   inflating: celebA/img/197829.jpg
#   inflating: celebA/img/197830.jpg
#   inflating: celebA/img/197831.jpg
#   inflating: celebA/img/197832.jpg
#   inflating: celebA/img/197833.jpg
#   inflating: celebA/img/197834.jpg
#   inflating: celebA/img/197835.jpg
#   inflating: celebA/img/197836.jpg
#   inflating: celebA/img/197837.jpg
#   inflating: celebA/img/197838.jpg
#   inflating: celebA/img/197839.jpg
#   inflating: celebA/img/197840.jpg
#   inflating: celebA/img/197841.jpg
#   inflating: celebA/img/197842.jpg
#   inflating: celebA/img/197843.jpg
#   inflating: celebA/img/197844.jpg
#   inflating: celebA/img/197845.jpg
#   inflating: celebA/img/197846.jpg
#   inflating: celebA/img/197847.jpg
#   inflating: celebA/img/197848.jpg
#   inflating: celebA/img/197849.jpg
#   inflating: celebA/img/197850.jpg
#   inflating: celebA/img/197851.jpg
#   inflating: celebA/img/197852.jpg
#   inflating: celebA/img/197853.jpg
#   inflating: celebA/img/197854.jpg
#   inflating: celebA/img/197855.jpg
#   inflating: celebA/img/197856.jpg
#   inflating: celebA/img/197857.jpg
#   inflating: celebA/img/197858.jpg
#   inflating: celebA/img/197859.jpg
#   inflating: celebA/img/197860.jpg
#   inflating: celebA/img/197861.jpg
#   inflating: celebA/img/197862.jpg
#   inflating: celebA/img/197863.jpg
#   inflating: celebA/img/197864.jpg
#   inflating: celebA/img/197865.jpg
#   inflating: celebA/img/197866.jpg
#   inflating: celebA/img/197867.jpg
#   inflating: celebA/img/197868.jpg
#   inflating: celebA/img/197869.jpg
#   inflating: celebA/img/197870.jpg
#   inflating: celebA/img/197871.jpg
#   inflating: celebA/img/197872.jpg
#   inflating: celebA/img/197873.jpg
#   inflating: celebA/img/197874.jpg
#   inflating: celebA/img/197875.jpg
#   inflating: celebA/img/197876.jpg
#   inflating: celebA/img/197877.jpg
#   inflating: celebA/img/197878.jpg
#   inflating: celebA/img/197879.jpg
#   inflating: celebA/img/197880.jpg
#   inflating: celebA/img/197881.jpg
#   inflating: celebA/img/197882.jpg
#   inflating: celebA/img/197883.jpg
#   inflating: celebA/img/197884.jpg
#   inflating: celebA/img/197885.jpg
#   inflating: celebA/img/197886.jpg
#   inflating: celebA/img/197887.jpg
#   inflating: celebA/img/197888.jpg
#   inflating: celebA/img/197889.jpg
#   inflating: celebA/img/197890.jpg
#   inflating: celebA/img/197891.jpg
#   inflating: celebA/img/197892.jpg
#   inflating: celebA/img/197893.jpg
#   inflating: celebA/img/197894.jpg
#   inflating: celebA/img/197895.jpg
#   inflating: celebA/img/197896.jpg
#   inflating: celebA/img/197897.jpg
#   inflating: celebA/img/197898.jpg
#   inflating: celebA/img/197899.jpg
#   inflating: celebA/img/197900.jpg
#   inflating: celebA/img/197901.jpg
#   inflating: celebA/img/197902.jpg
#   inflating: celebA/img/197903.jpg
#   inflating: celebA/img/197904.jpg
#   inflating: celebA/img/197905.jpg
#   inflating: celebA/img/197906.jpg
#   inflating: celebA/img/197907.jpg
#   inflating: celebA/img/197908.jpg
#   inflating: celebA/img/197909.jpg
#   inflating: celebA/img/197910.jpg
#   inflating: celebA/img/197911.jpg
#   inflating: celebA/img/197912.jpg
#   inflating: celebA/img/197913.jpg
#   inflating: celebA/img/197914.jpg
#   inflating: celebA/img/197915.jpg
#   inflating: celebA/img/197916.jpg
#   inflating: celebA/img/197917.jpg
#   inflating: celebA/img/197918.jpg
#   inflating: celebA/img/197919.jpg
#   inflating: celebA/img/197920.jpg
#   inflating: celebA/img/197921.jpg
#   inflating: celebA/img/197922.jpg
#   inflating: celebA/img/197923.jpg
#   inflating: celebA/img/197924.jpg
#   inflating: celebA/img/197925.jpg
#   inflating: celebA/img/197926.jpg
#   inflating: celebA/img/197927.jpg
#   inflating: celebA/img/197928.jpg
#   inflating: celebA/img/197929.jpg
#   inflating: celebA/img/197930.jpg
#   inflating: celebA/img/197931.jpg
#   inflating: celebA/img/197932.jpg
#   inflating: celebA/img/197933.jpg
#   inflating: celebA/img/197934.jpg
#   inflating: celebA/img/197935.jpg
#   inflating: celebA/img/197936.jpg
#   inflating: celebA/img/197937.jpg
#   inflating: celebA/img/197938.jpg
#   inflating: celebA/img/197939.jpg
#   inflating: celebA/img/197940.jpg
#   inflating: celebA/img/197941.jpg
#   inflating: celebA/img/197942.jpg
#   inflating: celebA/img/197943.jpg
#   inflating: celebA/img/197944.jpg
#   inflating: celebA/img/197945.jpg
#   inflating: celebA/img/197946.jpg
#   inflating: celebA/img/197947.jpg
#   inflating: celebA/img/197948.jpg
#   inflating: celebA/img/197949.jpg
#   inflating: celebA/img/197950.jpg
#   inflating: celebA/img/197951.jpg
#   inflating: celebA/img/197952.jpg
#   inflating: celebA/img/197953.jpg
#   inflating: celebA/img/197954.jpg
#   inflating: celebA/img/197955.jpg
#   inflating: celebA/img/197956.jpg
#   inflating: celebA/img/197957.jpg
#   inflating: celebA/img/197958.jpg
#   inflating: celebA/img/197959.jpg
#   inflating: celebA/img/197960.jpg
#   inflating: celebA/img/197961.jpg
#   inflating: celebA/img/197962.jpg
#   inflating: celebA/img/197963.jpg
#   inflating: celebA/img/197964.jpg
#   inflating: celebA/img/197965.jpg
#   inflating: celebA/img/197966.jpg
#   inflating: celebA/img/197967.jpg
#   inflating: celebA/img/197968.jpg
#   inflating: celebA/img/197969.jpg
#   inflating: celebA/img/197970.jpg
#   inflating: celebA/img/197971.jpg
#   inflating: celebA/img/197972.jpg
#   inflating: celebA/img/197973.jpg
#   inflating: celebA/img/197974.jpg
#   inflating: celebA/img/197975.jpg
#   inflating: celebA/img/197976.jpg
#   inflating: celebA/img/197977.jpg
#   inflating: celebA/img/197978.jpg
#   inflating: celebA/img/197979.jpg
#   inflating: celebA/img/197980.jpg
#   inflating: celebA/img/197981.jpg
#   inflating: celebA/img/197982.jpg
#   inflating: celebA/img/197983.jpg
#   inflating: celebA/img/197984.jpg
#   inflating: celebA/img/197985.jpg
#   inflating: celebA/img/197986.jpg
#   inflating: celebA/img/197987.jpg
#   inflating: celebA/img/197988.jpg
#   inflating: celebA/img/197989.jpg
#   inflating: celebA/img/197990.jpg
#   inflating: celebA/img/197991.jpg
#   inflating: celebA/img/197992.jpg
#   inflating: celebA/img/197993.jpg
#   inflating: celebA/img/197994.jpg
#   inflating: celebA/img/197995.jpg
#   inflating: celebA/img/197996.jpg
#   inflating: celebA/img/197997.jpg
#   inflating: celebA/img/197998.jpg
#   inflating: celebA/img/197999.jpg
#   inflating: celebA/img/198000.jpg
#   inflating: celebA/img/198001.jpg
#   inflating: celebA/img/198002.jpg
#   inflating: celebA/img/198003.jpg
#   inflating: celebA/img/198004.jpg
#   inflating: celebA/img/198005.jpg
#   inflating: celebA/img/198006.jpg
#   inflating: celebA/img/198007.jpg
#   inflating: celebA/img/198008.jpg
#   inflating: celebA/img/198009.jpg
#   inflating: celebA/img/198010.jpg
#   inflating: celebA/img/198011.jpg
#   inflating: celebA/img/198012.jpg
#   inflating: celebA/img/198013.jpg
#   inflating: celebA/img/198014.jpg
#   inflating: celebA/img/198015.jpg
#   inflating: celebA/img/198016.jpg
#   inflating: celebA/img/198017.jpg
#   inflating: celebA/img/198018.jpg
#   inflating: celebA/img/198019.jpg
#   inflating: celebA/img/198020.jpg
#   inflating: celebA/img/198021.jpg
#   inflating: celebA/img/198022.jpg
#   inflating: celebA/img/198023.jpg
#   inflating: celebA/img/198024.jpg
#   inflating: celebA/img/198025.jpg
#   inflating: celebA/img/198026.jpg
#   inflating: celebA/img/198027.jpg
#   inflating: celebA/img/198028.jpg
#   inflating: celebA/img/198029.jpg
#   inflating: celebA/img/198030.jpg
#   inflating: celebA/img/198031.jpg
#   inflating: celebA/img/198032.jpg
#   inflating: celebA/img/198033.jpg
#   inflating: celebA/img/198034.jpg
#   inflating: celebA/img/198035.jpg
#   inflating: celebA/img/198036.jpg
#   inflating: celebA/img/198037.jpg
#   inflating: celebA/img/198038.jpg
#   inflating: celebA/img/198039.jpg
#   inflating: celebA/img/198040.jpg
#   inflating: celebA/img/198041.jpg
#   inflating: celebA/img/198042.jpg
#   inflating: celebA/img/198043.jpg
#   inflating: celebA/img/198044.jpg
#   inflating: celebA/img/198045.jpg
#   inflating: celebA/img/198046.jpg
#   inflating: celebA/img/198047.jpg
#   inflating: celebA/img/198048.jpg
#   inflating: celebA/img/198049.jpg
#   inflating: celebA/img/198050.jpg
#   inflating: celebA/img/198051.jpg
#   inflating: celebA/img/198052.jpg
#   inflating: celebA/img/198053.jpg
#   inflating: celebA/img/198054.jpg
#   inflating: celebA/img/198055.jpg
#   inflating: celebA/img/198056.jpg
#   inflating: celebA/img/198057.jpg
#   inflating: celebA/img/198058.jpg
#   inflating: celebA/img/198059.jpg
#   inflating: celebA/img/198060.jpg
#   inflating: celebA/img/198061.jpg
#   inflating: celebA/img/198062.jpg
#   inflating: celebA/img/198063.jpg
#   inflating: celebA/img/198064.jpg
#   inflating: celebA/img/198065.jpg
#   inflating: celebA/img/198066.jpg
#   inflating: celebA/img/198067.jpg
#   inflating: celebA/img/198068.jpg
#   inflating: celebA/img/198069.jpg
#   inflating: celebA/img/198070.jpg
#   inflating: celebA/img/198071.jpg
#   inflating: celebA/img/198072.jpg
#   inflating: celebA/img/198073.jpg
#   inflating: celebA/img/198074.jpg
#   inflating: celebA/img/198075.jpg
#   inflating: celebA/img/198076.jpg
#   inflating: celebA/img/198077.jpg
#   inflating: celebA/img/198078.jpg
#   inflating: celebA/img/198079.jpg
#   inflating: celebA/img/198080.jpg
#   inflating: celebA/img/198081.jpg
#   inflating: celebA/img/198082.jpg
#   inflating: celebA/img/198083.jpg
#   inflating: celebA/img/198084.jpg
#   inflating: celebA/img/198085.jpg
#   inflating: celebA/img/198086.jpg
#   inflating: celebA/img/198087.jpg
#   inflating: celebA/img/198088.jpg
#   inflating: celebA/img/198089.jpg
#   inflating: celebA/img/198090.jpg
#   inflating: celebA/img/198091.jpg
#   inflating: celebA/img/198092.jpg
#   inflating: celebA/img/198093.jpg
#   inflating: celebA/img/198094.jpg
#   inflating: celebA/img/198095.jpg
#   inflating: celebA/img/198096.jpg
#   inflating: celebA/img/198097.jpg
#   inflating: celebA/img/198098.jpg
#   inflating: celebA/img/198099.jpg
#   inflating: celebA/img/198100.jpg
#   inflating: celebA/img/198101.jpg
#   inflating: celebA/img/198102.jpg
#   inflating: celebA/img/198103.jpg
#   inflating: celebA/img/198104.jpg
#   inflating: celebA/img/198105.jpg
#   inflating: celebA/img/198106.jpg
#   inflating: celebA/img/198107.jpg
#   inflating: celebA/img/198108.jpg
#   inflating: celebA/img/198109.jpg
#   inflating: celebA/img/198110.jpg
#   inflating: celebA/img/198111.jpg
#   inflating: celebA/img/198112.jpg
#   inflating: celebA/img/198113.jpg
#   inflating: celebA/img/198114.jpg
#   inflating: celebA/img/198115.jpg
#   inflating: celebA/img/198116.jpg
#   inflating: celebA/img/198117.jpg
#   inflating: celebA/img/198118.jpg
#   inflating: celebA/img/198119.jpg
#   inflating: celebA/img/198120.jpg
#   inflating: celebA/img/198121.jpg
#   inflating: celebA/img/198122.jpg
#   inflating: celebA/img/198123.jpg
#   inflating: celebA/img/198124.jpg
#   inflating: celebA/img/198125.jpg
#   inflating: celebA/img/198126.jpg
#   inflating: celebA/img/198127.jpg
#   inflating: celebA/img/198128.jpg
#   inflating: celebA/img/198129.jpg
#   inflating: celebA/img/198130.jpg
#   inflating: celebA/img/198131.jpg
#   inflating: celebA/img/198132.jpg
#   inflating: celebA/img/198133.jpg
#   inflating: celebA/img/198134.jpg
#   inflating: celebA/img/198135.jpg
#   inflating: celebA/img/198136.jpg
#   inflating: celebA/img/198137.jpg
#   inflating: celebA/img/198138.jpg
#   inflating: celebA/img/198139.jpg
#   inflating: celebA/img/198140.jpg
#   inflating: celebA/img/198141.jpg
#   inflating: celebA/img/198142.jpg
#   inflating: celebA/img/198143.jpg
#   inflating: celebA/img/198144.jpg
#   inflating: celebA/img/198145.jpg
#   inflating: celebA/img/198146.jpg
#   inflating: celebA/img/198147.jpg
#   inflating: celebA/img/198148.jpg
#   inflating: celebA/img/198149.jpg
#   inflating: celebA/img/198150.jpg
#   inflating: celebA/img/198151.jpg
#   inflating: celebA/img/198152.jpg
#   inflating: celebA/img/198153.jpg
#   inflating: celebA/img/198154.jpg
#   inflating: celebA/img/198155.jpg
#   inflating: celebA/img/198156.jpg
#   inflating: celebA/img/198157.jpg
#   inflating: celebA/img/198158.jpg
#   inflating: celebA/img/198159.jpg
#   inflating: celebA/img/198160.jpg
#   inflating: celebA/img/198161.jpg
#   inflating: celebA/img/198162.jpg
#   inflating: celebA/img/198163.jpg
#   inflating: celebA/img/198164.jpg
#   inflating: celebA/img/198165.jpg
#   inflating: celebA/img/198166.jpg
#   inflating: celebA/img/198167.jpg
#   inflating: celebA/img/198168.jpg
#   inflating: celebA/img/198169.jpg
#   inflating: celebA/img/198170.jpg
#   inflating: celebA/img/198171.jpg
#   inflating: celebA/img/198172.jpg
#   inflating: celebA/img/198173.jpg
#   inflating: celebA/img/198174.jpg
#   inflating: celebA/img/198175.jpg
#   inflating: celebA/img/198176.jpg
#   inflating: celebA/img/198177.jpg
#   inflating: celebA/img/198178.jpg
#   inflating: celebA/img/198179.jpg
#   inflating: celebA/img/198180.jpg
#   inflating: celebA/img/198181.jpg
#   inflating: celebA/img/198182.jpg
#   inflating: celebA/img/198183.jpg
#   inflating: celebA/img/198184.jpg
#   inflating: celebA/img/198185.jpg
#   inflating: celebA/img/198186.jpg
#   inflating: celebA/img/198187.jpg
#   inflating: celebA/img/198188.jpg
#   inflating: celebA/img/198189.jpg
#   inflating: celebA/img/198190.jpg
#   inflating: celebA/img/198191.jpg
#   inflating: celebA/img/198192.jpg
#   inflating: celebA/img/198193.jpg
#   inflating: celebA/img/198194.jpg
#   inflating: celebA/img/198195.jpg
#   inflating: celebA/img/198196.jpg
#   inflating: celebA/img/198197.jpg
#   inflating: celebA/img/198198.jpg
#   inflating: celebA/img/198199.jpg
#   inflating: celebA/img/198200.jpg
#   inflating: celebA/img/198201.jpg
#   inflating: celebA/img/198202.jpg
#   inflating: celebA/img/198203.jpg
#   inflating: celebA/img/198204.jpg
#   inflating: celebA/img/198205.jpg
#   inflating: celebA/img/198206.jpg
#   inflating: celebA/img/198207.jpg
#   inflating: celebA/img/198208.jpg
#   inflating: celebA/img/198209.jpg
#   inflating: celebA/img/198210.jpg
#   inflating: celebA/img/198211.jpg
#   inflating: celebA/img/198212.jpg
#   inflating: celebA/img/198213.jpg
#   inflating: celebA/img/198214.jpg
#   inflating: celebA/img/198215.jpg
#   inflating: celebA/img/198216.jpg
#   inflating: celebA/img/198217.jpg
#   inflating: celebA/img/198218.jpg
#   inflating: celebA/img/198219.jpg
#   inflating: celebA/img/198220.jpg
#   inflating: celebA/img/198221.jpg
#   inflating: celebA/img/198222.jpg
#   inflating: celebA/img/198223.jpg
#   inflating: celebA/img/198224.jpg
#   inflating: celebA/img/198225.jpg
#   inflating: celebA/img/198226.jpg
#   inflating: celebA/img/198227.jpg
#   inflating: celebA/img/198228.jpg
#   inflating: celebA/img/198229.jpg
#   inflating: celebA/img/198230.jpg
#   inflating: celebA/img/198231.jpg
#   inflating: celebA/img/198232.jpg
#   inflating: celebA/img/198233.jpg
#   inflating: celebA/img/198234.jpg
#   inflating: celebA/img/198235.jpg
#   inflating: celebA/img/198236.jpg
#   inflating: celebA/img/198237.jpg
#   inflating: celebA/img/198238.jpg
#   inflating: celebA/img/198239.jpg
#   inflating: celebA/img/198240.jpg
#   inflating: celebA/img/198241.jpg
#   inflating: celebA/img/198242.jpg
#   inflating: celebA/img/198243.jpg
#   inflating: celebA/img/198244.jpg
#   inflating: celebA/img/198245.jpg
#   inflating: celebA/img/198246.jpg
#   inflating: celebA/img/198247.jpg
#   inflating: celebA/img/198248.jpg
#   inflating: celebA/img/198249.jpg
#   inflating: celebA/img/198250.jpg
#   inflating: celebA/img/198251.jpg
#   inflating: celebA/img/198252.jpg
#   inflating: celebA/img/198253.jpg
#   inflating: celebA/img/198254.jpg
#   inflating: celebA/img/198255.jpg
#   inflating: celebA/img/198256.jpg
#   inflating: celebA/img/198257.jpg
#   inflating: celebA/img/198258.jpg
#   inflating: celebA/img/198259.jpg
#   inflating: celebA/img/198260.jpg
#   inflating: celebA/img/198261.jpg
#   inflating: celebA/img/198262.jpg
#   inflating: celebA/img/198263.jpg
#   inflating: celebA/img/198264.jpg
#   inflating: celebA/img/198265.jpg
#   inflating: celebA/img/198266.jpg
#   inflating: celebA/img/198267.jpg
#   inflating: celebA/img/198268.jpg
#   inflating: celebA/img/198269.jpg
#   inflating: celebA/img/198270.jpg
#   inflating: celebA/img/198271.jpg
#   inflating: celebA/img/198272.jpg
#   inflating: celebA/img/198273.jpg
#   inflating: celebA/img/198274.jpg
#   inflating: celebA/img/198275.jpg
#   inflating: celebA/img/198276.jpg
#   inflating: celebA/img/198277.jpg
#   inflating: celebA/img/198278.jpg
#   inflating: celebA/img/198279.jpg
#   inflating: celebA/img/198280.jpg
#   inflating: celebA/img/198281.jpg
#   inflating: celebA/img/198282.jpg
#   inflating: celebA/img/198283.jpg
#   inflating: celebA/img/198284.jpg
#   inflating: celebA/img/198285.jpg
#   inflating: celebA/img/198286.jpg
#   inflating: celebA/img/198287.jpg
#   inflating: celebA/img/198288.jpg
#   inflating: celebA/img/198289.jpg
#   inflating: celebA/img/198290.jpg
#   inflating: celebA/img/198291.jpg
#   inflating: celebA/img/198292.jpg
#   inflating: celebA/img/198293.jpg
#   inflating: celebA/img/198294.jpg
#   inflating: celebA/img/198295.jpg
#   inflating: celebA/img/198296.jpg
#   inflating: celebA/img/198297.jpg
#   inflating: celebA/img/198298.jpg
#   inflating: celebA/img/198299.jpg
#   inflating: celebA/img/198300.jpg
#   inflating: celebA/img/198301.jpg
#   inflating: celebA/img/198302.jpg
#   inflating: celebA/img/198303.jpg
#   inflating: celebA/img/198304.jpg
#   inflating: celebA/img/198305.jpg
#   inflating: celebA/img/198306.jpg
#   inflating: celebA/img/198307.jpg
#   inflating: celebA/img/198308.jpg
#   inflating: celebA/img/198309.jpg
#   inflating: celebA/img/198310.jpg
#   inflating: celebA/img/198311.jpg
#   inflating: celebA/img/198312.jpg
#   inflating: celebA/img/198313.jpg
#   inflating: celebA/img/198314.jpg
#   inflating: celebA/img/198315.jpg
#   inflating: celebA/img/198316.jpg
#   inflating: celebA/img/198317.jpg
#   inflating: celebA/img/198318.jpg
#   inflating: celebA/img/198319.jpg
#   inflating: celebA/img/198320.jpg
#   inflating: celebA/img/198321.jpg
#   inflating: celebA/img/198322.jpg
#   inflating: celebA/img/198323.jpg
#   inflating: celebA/img/198324.jpg
#   inflating: celebA/img/198325.jpg
#   inflating: celebA/img/198326.jpg
#   inflating: celebA/img/198327.jpg
#   inflating: celebA/img/198328.jpg
#   inflating: celebA/img/198329.jpg
#   inflating: celebA/img/198330.jpg
#   inflating: celebA/img/198331.jpg
#   inflating: celebA/img/198332.jpg
#   inflating: celebA/img/198333.jpg
#   inflating: celebA/img/198334.jpg
#   inflating: celebA/img/198335.jpg
#   inflating: celebA/img/198336.jpg
#   inflating: celebA/img/198337.jpg
#   inflating: celebA/img/198338.jpg
#   inflating: celebA/img/198339.jpg
#   inflating: celebA/img/198340.jpg
#   inflating: celebA/img/198341.jpg
#   inflating: celebA/img/198342.jpg
#   inflating: celebA/img/198343.jpg
#   inflating: celebA/img/198344.jpg
#   inflating: celebA/img/198345.jpg
#   inflating: celebA/img/198346.jpg
#   inflating: celebA/img/198347.jpg
#   inflating: celebA/img/198348.jpg
#   inflating: celebA/img/198349.jpg
#   inflating: celebA/img/198350.jpg
#   inflating: celebA/img/198351.jpg
#   inflating: celebA/img/198352.jpg
#   inflating: celebA/img/198353.jpg
#   inflating: celebA/img/198354.jpg
#   inflating: celebA/img/198355.jpg
#   inflating: celebA/img/198356.jpg
#   inflating: celebA/img/198357.jpg
#   inflating: celebA/img/198358.jpg
#   inflating: celebA/img/198359.jpg
#   inflating: celebA/img/198360.jpg
#   inflating: celebA/img/198361.jpg
#   inflating: celebA/img/198362.jpg
#   inflating: celebA/img/198363.jpg
#   inflating: celebA/img/198364.jpg
#   inflating: celebA/img/198365.jpg
#   inflating: celebA/img/198366.jpg
#   inflating: celebA/img/198367.jpg
#   inflating: celebA/img/198368.jpg
#   inflating: celebA/img/198369.jpg
#   inflating: celebA/img/198370.jpg
#   inflating: celebA/img/198371.jpg
#   inflating: celebA/img/198372.jpg
#   inflating: celebA/img/198373.jpg
#   inflating: celebA/img/198374.jpg
#   inflating: celebA/img/198375.jpg
#   inflating: celebA/img/198376.jpg
#   inflating: celebA/img/198377.jpg
#   inflating: celebA/img/198378.jpg
#   inflating: celebA/img/198379.jpg
#   inflating: celebA/img/198380.jpg
#   inflating: celebA/img/198381.jpg
#   inflating: celebA/img/198382.jpg
#   inflating: celebA/img/198383.jpg
#   inflating: celebA/img/198384.jpg
#   inflating: celebA/img/198385.jpg
#   inflating: celebA/img/198386.jpg
#   inflating: celebA/img/198387.jpg
#   inflating: celebA/img/198388.jpg
#   inflating: celebA/img/198389.jpg
#   inflating: celebA/img/198390.jpg
#   inflating: celebA/img/198391.jpg
#   inflating: celebA/img/198392.jpg
#   inflating: celebA/img/198393.jpg
#   inflating: celebA/img/198394.jpg
#   inflating: celebA/img/198395.jpg
#   inflating: celebA/img/198396.jpg
#   inflating: celebA/img/198397.jpg
#   inflating: celebA/img/198398.jpg
#   inflating: celebA/img/198399.jpg
#   inflating: celebA/img/198400.jpg
#   inflating: celebA/img/198401.jpg
#   inflating: celebA/img/198402.jpg
#   inflating: celebA/img/198403.jpg
#   inflating: celebA/img/198404.jpg
#   inflating: celebA/img/198405.jpg
#   inflating: celebA/img/198406.jpg
#   inflating: celebA/img/198407.jpg
#   inflating: celebA/img/198408.jpg
#   inflating: celebA/img/198409.jpg
#   inflating: celebA/img/198410.jpg
#   inflating: celebA/img/198411.jpg
#   inflating: celebA/img/198412.jpg
#   inflating: celebA/img/198413.jpg
#   inflating: celebA/img/198414.jpg
#   inflating: celebA/img/198415.jpg
#   inflating: celebA/img/198416.jpg
#   inflating: celebA/img/198417.jpg
#   inflating: celebA/img/198418.jpg
#   inflating: celebA/img/198419.jpg
#   inflating: celebA/img/198420.jpg
#   inflating: celebA/img/198421.jpg
#   inflating: celebA/img/198422.jpg
#   inflating: celebA/img/198423.jpg
#   inflating: celebA/img/198424.jpg
#   inflating: celebA/img/198425.jpg
#   inflating: celebA/img/198426.jpg
#   inflating: celebA/img/198427.jpg
#   inflating: celebA/img/198428.jpg
#   inflating: celebA/img/198429.jpg
#   inflating: celebA/img/198430.jpg
#   inflating: celebA/img/198431.jpg
#   inflating: celebA/img/198432.jpg
#   inflating: celebA/img/198433.jpg
#   inflating: celebA/img/198434.jpg
#   inflating: celebA/img/198435.jpg
#   inflating: celebA/img/198436.jpg
#   inflating: celebA/img/198437.jpg
#   inflating: celebA/img/198438.jpg
#   inflating: celebA/img/198439.jpg
#   inflating: celebA/img/198440.jpg
#   inflating: celebA/img/198441.jpg
#   inflating: celebA/img/198442.jpg
#   inflating: celebA/img/198443.jpg
#   inflating: celebA/img/198444.jpg
#   inflating: celebA/img/198445.jpg
#   inflating: celebA/img/198446.jpg
#   inflating: celebA/img/198447.jpg
#   inflating: celebA/img/198448.jpg
#   inflating: celebA/img/198449.jpg
#   inflating: celebA/img/198450.jpg
#   inflating: celebA/img/198451.jpg
#   inflating: celebA/img/198452.jpg
#   inflating: celebA/img/198453.jpg
#   inflating: celebA/img/198454.jpg
#   inflating: celebA/img/198455.jpg
#   inflating: celebA/img/198456.jpg
#   inflating: celebA/img/198457.jpg
#   inflating: celebA/img/198458.jpg
#   inflating: celebA/img/198459.jpg
#   inflating: celebA/img/198460.jpg
#   inflating: celebA/img/198461.jpg
#   inflating: celebA/img/198462.jpg
#   inflating: celebA/img/198463.jpg
#   inflating: celebA/img/198464.jpg
#   inflating: celebA/img/198465.jpg
#   inflating: celebA/img/198466.jpg
#   inflating: celebA/img/198467.jpg
#   inflating: celebA/img/198468.jpg
#   inflating: celebA/img/198469.jpg
#   inflating: celebA/img/198470.jpg
#   inflating: celebA/img/198471.jpg
#   inflating: celebA/img/198472.jpg
#   inflating: celebA/img/198473.jpg
#   inflating: celebA/img/198474.jpg
#   inflating: celebA/img/198475.jpg
#   inflating: celebA/img/198476.jpg
#   inflating: celebA/img/198477.jpg
#   inflating: celebA/img/198478.jpg
#   inflating: celebA/img/198479.jpg
#   inflating: celebA/img/198480.jpg
#   inflating: celebA/img/198481.jpg
#   inflating: celebA/img/198482.jpg
#   inflating: celebA/img/198483.jpg
#   inflating: celebA/img/198484.jpg
#   inflating: celebA/img/198485.jpg
#   inflating: celebA/img/198486.jpg
#   inflating: celebA/img/198487.jpg
#   inflating: celebA/img/198488.jpg
#   inflating: celebA/img/198489.jpg
#   inflating: celebA/img/198490.jpg
#   inflating: celebA/img/198491.jpg
#   inflating: celebA/img/198492.jpg
#   inflating: celebA/img/198493.jpg
#   inflating: celebA/img/198494.jpg
#   inflating: celebA/img/198495.jpg
#   inflating: celebA/img/198496.jpg
#   inflating: celebA/img/198497.jpg
#   inflating: celebA/img/198498.jpg
#   inflating: celebA/img/198499.jpg
#   inflating: celebA/img/198500.jpg
#   inflating: celebA/img/198501.jpg
#   inflating: celebA/img/198502.jpg
#   inflating: celebA/img/198503.jpg
#   inflating: celebA/img/198504.jpg
#   inflating: celebA/img/198505.jpg
#   inflating: celebA/img/198506.jpg
#   inflating: celebA/img/198507.jpg
#   inflating: celebA/img/198508.jpg
#   inflating: celebA/img/198509.jpg
#   inflating: celebA/img/198510.jpg
#   inflating: celebA/img/198511.jpg
#   inflating: celebA/img/198512.jpg
#   inflating: celebA/img/198513.jpg
#   inflating: celebA/img/198514.jpg
#   inflating: celebA/img/198515.jpg
#   inflating: celebA/img/198516.jpg
#   inflating: celebA/img/198517.jpg
#   inflating: celebA/img/198518.jpg
#   inflating: celebA/img/198519.jpg
#   inflating: celebA/img/198520.jpg
#   inflating: celebA/img/198521.jpg
#   inflating: celebA/img/198522.jpg
#   inflating: celebA/img/198523.jpg
#   inflating: celebA/img/198524.jpg
#   inflating: celebA/img/198525.jpg
#   inflating: celebA/img/198526.jpg
#   inflating: celebA/img/198527.jpg
#   inflating: celebA/img/198528.jpg
#   inflating: celebA/img/198529.jpg
#   inflating: celebA/img/198530.jpg
#   inflating: celebA/img/198531.jpg
#   inflating: celebA/img/198532.jpg
#   inflating: celebA/img/198533.jpg
#   inflating: celebA/img/198534.jpg
#   inflating: celebA/img/198535.jpg
#   inflating: celebA/img/198536.jpg
#   inflating: celebA/img/198537.jpg
#   inflating: celebA/img/198538.jpg
#   inflating: celebA/img/198539.jpg
#   inflating: celebA/img/198540.jpg
#   inflating: celebA/img/198541.jpg
#   inflating: celebA/img/198542.jpg
#   inflating: celebA/img/198543.jpg
#   inflating: celebA/img/198544.jpg
#   inflating: celebA/img/198545.jpg
#   inflating: celebA/img/198546.jpg
#   inflating: celebA/img/198547.jpg
#   inflating: celebA/img/198548.jpg
#   inflating: celebA/img/198549.jpg
#   inflating: celebA/img/198550.jpg
#   inflating: celebA/img/198551.jpg
#   inflating: celebA/img/198552.jpg
#   inflating: celebA/img/198553.jpg
#   inflating: celebA/img/198554.jpg
#   inflating: celebA/img/198555.jpg
#   inflating: celebA/img/198556.jpg
#   inflating: celebA/img/198557.jpg
#   inflating: celebA/img/198558.jpg
#   inflating: celebA/img/198559.jpg
#   inflating: celebA/img/198560.jpg
#   inflating: celebA/img/198561.jpg
#   inflating: celebA/img/198562.jpg
#   inflating: celebA/img/198563.jpg
#   inflating: celebA/img/198564.jpg
#   inflating: celebA/img/198565.jpg
#   inflating: celebA/img/198566.jpg
#   inflating: celebA/img/198567.jpg
#   inflating: celebA/img/198568.jpg
#   inflating: celebA/img/198569.jpg
#   inflating: celebA/img/198570.jpg
#   inflating: celebA/img/198571.jpg
#   inflating: celebA/img/198572.jpg
#   inflating: celebA/img/198573.jpg
#   inflating: celebA/img/198574.jpg
#   inflating: celebA/img/198575.jpg
#   inflating: celebA/img/198576.jpg
#   inflating: celebA/img/198577.jpg
#   inflating: celebA/img/198578.jpg
#   inflating: celebA/img/198579.jpg
#   inflating: celebA/img/198580.jpg
#   inflating: celebA/img/198581.jpg
#   inflating: celebA/img/198582.jpg
#   inflating: celebA/img/198583.jpg
#   inflating: celebA/img/198584.jpg
#   inflating: celebA/img/198585.jpg
#   inflating: celebA/img/198586.jpg
#   inflating: celebA/img/198587.jpg
#   inflating: celebA/img/198588.jpg
#   inflating: celebA/img/198589.jpg
#   inflating: celebA/img/198590.jpg
#   inflating: celebA/img/198591.jpg
#   inflating: celebA/img/198592.jpg
#   inflating: celebA/img/198593.jpg
#   inflating: celebA/img/198594.jpg
#   inflating: celebA/img/198595.jpg
#   inflating: celebA/img/198596.jpg
#   inflating: celebA/img/198597.jpg
#   inflating: celebA/img/198598.jpg
#   inflating: celebA/img/198599.jpg
#   inflating: celebA/img/198600.jpg
#   inflating: celebA/img/198601.jpg
#   inflating: celebA/img/198602.jpg
#   inflating: celebA/img/198603.jpg
#   inflating: celebA/img/198604.jpg
#   inflating: celebA/img/198605.jpg
#   inflating: celebA/img/198606.jpg
#   inflating: celebA/img/198607.jpg
#   inflating: celebA/img/198608.jpg
#   inflating: celebA/img/198609.jpg
#   inflating: celebA/img/198610.jpg
#   inflating: celebA/img/198611.jpg
#   inflating: celebA/img/198612.jpg
#   inflating: celebA/img/198613.jpg
#   inflating: celebA/img/198614.jpg
#   inflating: celebA/img/198615.jpg
#   inflating: celebA/img/198616.jpg
#   inflating: celebA/img/198617.jpg
#   inflating: celebA/img/198618.jpg
#   inflating: celebA/img/198619.jpg
#   inflating: celebA/img/198620.jpg
#   inflating: celebA/img/198621.jpg
#   inflating: celebA/img/198622.jpg
#   inflating: celebA/img/198623.jpg
#   inflating: celebA/img/198624.jpg
#   inflating: celebA/img/198625.jpg
#   inflating: celebA/img/198626.jpg
#   inflating: celebA/img/198627.jpg
#   inflating: celebA/img/198628.jpg
#   inflating: celebA/img/198629.jpg
#   inflating: celebA/img/198630.jpg
#   inflating: celebA/img/198631.jpg
#   inflating: celebA/img/198632.jpg
#   inflating: celebA/img/198633.jpg
#   inflating: celebA/img/198634.jpg
#   inflating: celebA/img/198635.jpg
#   inflating: celebA/img/198636.jpg
#   inflating: celebA/img/198637.jpg
#   inflating: celebA/img/198638.jpg
#   inflating: celebA/img/198639.jpg
#   inflating: celebA/img/198640.jpg
#   inflating: celebA/img/198641.jpg
#   inflating: celebA/img/198642.jpg
#   inflating: celebA/img/198643.jpg
#   inflating: celebA/img/198644.jpg
#   inflating: celebA/img/198645.jpg
#   inflating: celebA/img/198646.jpg
#   inflating: celebA/img/198647.jpg
#   inflating: celebA/img/198648.jpg
#   inflating: celebA/img/198649.jpg
#   inflating: celebA/img/198650.jpg
#   inflating: celebA/img/198651.jpg
#   inflating: celebA/img/198652.jpg
#   inflating: celebA/img/198653.jpg
#   inflating: celebA/img/198654.jpg
#   inflating: celebA/img/198655.jpg
#   inflating: celebA/img/198656.jpg
#   inflating: celebA/img/198657.jpg
#   inflating: celebA/img/198658.jpg
#   inflating: celebA/img/198659.jpg
#   inflating: celebA/img/198660.jpg
#   inflating: celebA/img/198661.jpg
#   inflating: celebA/img/198662.jpg
#   inflating: celebA/img/198663.jpg
#   inflating: celebA/img/198664.jpg
#   inflating: celebA/img/198665.jpg
#   inflating: celebA/img/198666.jpg
#   inflating: celebA/img/198667.jpg
#   inflating: celebA/img/198668.jpg
#   inflating: celebA/img/198669.jpg
#   inflating: celebA/img/198670.jpg
#   inflating: celebA/img/198671.jpg
#   inflating: celebA/img/198672.jpg
#   inflating: celebA/img/198673.jpg
#   inflating: celebA/img/198674.jpg
#   inflating: celebA/img/198675.jpg
#   inflating: celebA/img/198676.jpg
#   inflating: celebA/img/198677.jpg
#   inflating: celebA/img/198678.jpg
#   inflating: celebA/img/198679.jpg
#   inflating: celebA/img/198680.jpg
#   inflating: celebA/img/198681.jpg
#   inflating: celebA/img/198682.jpg
#   inflating: celebA/img/198683.jpg
#   inflating: celebA/img/198684.jpg
#   inflating: celebA/img/198685.jpg
#   inflating: celebA/img/198686.jpg
#   inflating: celebA/img/198687.jpg
#   inflating: celebA/img/198688.jpg
#   inflating: celebA/img/198689.jpg
#   inflating: celebA/img/198690.jpg
#   inflating: celebA/img/198691.jpg
#   inflating: celebA/img/198692.jpg
#   inflating: celebA/img/198693.jpg
#   inflating: celebA/img/198694.jpg
#   inflating: celebA/img/198695.jpg
#   inflating: celebA/img/198696.jpg
#   inflating: celebA/img/198697.jpg
#   inflating: celebA/img/198698.jpg
#   inflating: celebA/img/198699.jpg
#   inflating: celebA/img/198700.jpg
#   inflating: celebA/img/198701.jpg
#   inflating: celebA/img/198702.jpg
#   inflating: celebA/img/198703.jpg
#   inflating: celebA/img/198704.jpg
#   inflating: celebA/img/198705.jpg
#   inflating: celebA/img/198706.jpg
#   inflating: celebA/img/198707.jpg
#   inflating: celebA/img/198708.jpg
#   inflating: celebA/img/198709.jpg
#   inflating: celebA/img/198710.jpg
#   inflating: celebA/img/198711.jpg
#   inflating: celebA/img/198712.jpg
#   inflating: celebA/img/198713.jpg
#   inflating: celebA/img/198714.jpg
#   inflating: celebA/img/198715.jpg
#   inflating: celebA/img/198716.jpg
#   inflating: celebA/img/198717.jpg
#   inflating: celebA/img/198718.jpg
#   inflating: celebA/img/198719.jpg
#   inflating: celebA/img/198720.jpg
#   inflating: celebA/img/198721.jpg
#   inflating: celebA/img/198722.jpg
#   inflating: celebA/img/198723.jpg
#   inflating: celebA/img/198724.jpg
#   inflating: celebA/img/198725.jpg
#   inflating: celebA/img/198726.jpg
#   inflating: celebA/img/198727.jpg
#   inflating: celebA/img/198728.jpg
#   inflating: celebA/img/198729.jpg
#   inflating: celebA/img/198730.jpg
#   inflating: celebA/img/198731.jpg
#   inflating: celebA/img/198732.jpg
#   inflating: celebA/img/198733.jpg
#   inflating: celebA/img/198734.jpg
#   inflating: celebA/img/198735.jpg
#   inflating: celebA/img/198736.jpg
#   inflating: celebA/img/198737.jpg
#   inflating: celebA/img/198738.jpg
#   inflating: celebA/img/198739.jpg
#   inflating: celebA/img/198740.jpg
#   inflating: celebA/img/198741.jpg
#   inflating: celebA/img/198742.jpg
#   inflating: celebA/img/198743.jpg
#   inflating: celebA/img/198744.jpg
#   inflating: celebA/img/198745.jpg
#   inflating: celebA/img/198746.jpg
#   inflating: celebA/img/198747.jpg
#   inflating: celebA/img/198748.jpg
#   inflating: celebA/img/198749.jpg
#   inflating: celebA/img/198750.jpg
#   inflating: celebA/img/198751.jpg
#   inflating: celebA/img/198752.jpg
#   inflating: celebA/img/198753.jpg
#   inflating: celebA/img/198754.jpg
#   inflating: celebA/img/198755.jpg
#   inflating: celebA/img/198756.jpg
#   inflating: celebA/img/198757.jpg
#   inflating: celebA/img/198758.jpg
#   inflating: celebA/img/198759.jpg
#   inflating: celebA/img/198760.jpg
#   inflating: celebA/img/198761.jpg
#   inflating: celebA/img/198762.jpg
#   inflating: celebA/img/198763.jpg
#   inflating: celebA/img/198764.jpg
#   inflating: celebA/img/198765.jpg
#   inflating: celebA/img/198766.jpg
#   inflating: celebA/img/198767.jpg
#   inflating: celebA/img/198768.jpg
#   inflating: celebA/img/198769.jpg
#   inflating: celebA/img/198770.jpg
#   inflating: celebA/img/198771.jpg
#   inflating: celebA/img/198772.jpg
#   inflating: celebA/img/198773.jpg
#   inflating: celebA/img/198774.jpg
#   inflating: celebA/img/198775.jpg
#   inflating: celebA/img/198776.jpg
#   inflating: celebA/img/198777.jpg
#   inflating: celebA/img/198778.jpg
#   inflating: celebA/img/198779.jpg
#   inflating: celebA/img/198780.jpg
#   inflating: celebA/img/198781.jpg
#   inflating: celebA/img/198782.jpg
#   inflating: celebA/img/198783.jpg
#   inflating: celebA/img/198784.jpg
#   inflating: celebA/img/198785.jpg
#   inflating: celebA/img/198786.jpg
#   inflating: celebA/img/198787.jpg
#   inflating: celebA/img/198788.jpg
#   inflating: celebA/img/198789.jpg
#   inflating: celebA/img/198790.jpg
#   inflating: celebA/img/198791.jpg
#   inflating: celebA/img/198792.jpg
#   inflating: celebA/img/198793.jpg
#   inflating: celebA/img/198794.jpg
#   inflating: celebA/img/198795.jpg
#   inflating: celebA/img/198796.jpg
#   inflating: celebA/img/198797.jpg
#   inflating: celebA/img/198798.jpg
#   inflating: celebA/img/198799.jpg
#   inflating: celebA/img/198800.jpg
#   inflating: celebA/img/198801.jpg
#   inflating: celebA/img/198802.jpg
#   inflating: celebA/img/198803.jpg
#   inflating: celebA/img/198804.jpg
#   inflating: celebA/img/198805.jpg
#   inflating: celebA/img/198806.jpg
#   inflating: celebA/img/198807.jpg
#   inflating: celebA/img/198808.jpg
#   inflating: celebA/img/198809.jpg
#   inflating: celebA/img/198810.jpg
#   inflating: celebA/img/198811.jpg
#   inflating: celebA/img/198812.jpg
#   inflating: celebA/img/198813.jpg
#   inflating: celebA/img/198814.jpg
#   inflating: celebA/img/198815.jpg
#   inflating: celebA/img/198816.jpg
#   inflating: celebA/img/198817.jpg
#   inflating: celebA/img/198818.jpg
#   inflating: celebA/img/198819.jpg
#   inflating: celebA/img/198820.jpg
#   inflating: celebA/img/198821.jpg
#   inflating: celebA/img/198822.jpg
#   inflating: celebA/img/198823.jpg
#   inflating: celebA/img/198824.jpg
#   inflating: celebA/img/198825.jpg
#   inflating: celebA/img/198826.jpg
#   inflating: celebA/img/198827.jpg
#   inflating: celebA/img/198828.jpg
#   inflating: celebA/img/198829.jpg
#   inflating: celebA/img/198830.jpg
#   inflating: celebA/img/198831.jpg
#   inflating: celebA/img/198832.jpg
#   inflating: celebA/img/198833.jpg
#   inflating: celebA/img/198834.jpg
#   inflating: celebA/img/198835.jpg
#   inflating: celebA/img/198836.jpg
#   inflating: celebA/img/198837.jpg
#   inflating: celebA/img/198838.jpg
#   inflating: celebA/img/198839.jpg
#   inflating: celebA/img/198840.jpg
#   inflating: celebA/img/198841.jpg
#   inflating: celebA/img/198842.jpg
#   inflating: celebA/img/198843.jpg
#   inflating: celebA/img/198844.jpg
#   inflating: celebA/img/198845.jpg
#   inflating: celebA/img/198846.jpg
#   inflating: celebA/img/198847.jpg
#   inflating: celebA/img/198848.jpg
#   inflating: celebA/img/198849.jpg
#   inflating: celebA/img/198850.jpg
#   inflating: celebA/img/198851.jpg
#   inflating: celebA/img/198852.jpg
#   inflating: celebA/img/198853.jpg
#   inflating: celebA/img/198854.jpg
#   inflating: celebA/img/198855.jpg
#   inflating: celebA/img/198856.jpg
#   inflating: celebA/img/198857.jpg
#   inflating: celebA/img/198858.jpg
#   inflating: celebA/img/198859.jpg
#   inflating: celebA/img/198860.jpg
#   inflating: celebA/img/198861.jpg
#   inflating: celebA/img/198862.jpg
#   inflating: celebA/img/198863.jpg
#   inflating: celebA/img/198864.jpg
#   inflating: celebA/img/198865.jpg
#   inflating: celebA/img/198866.jpg
# ...
#   inflating: celebA/img/202185.jpg
#   inflating: celebA/img/202186.jpg
#   inflating: celebA/img/202187.jpg
#   inflating: celebA/img/202188.jpg
#   inflating: celebA/img/202189.jpg
#   inflating: celebA/img/202190.jpg
#   inflating: celebA/img/202191.jpg
#   inflating: celebA/img/202192.jpg
#   inflating: celebA/img/202193.jpg
#   inflating: celebA/img/202194.jpg
#   inflating: celebA/img/202195.jpg
#   inflating: celebA/img/202196.jpg
#   inflating: celebA/img/202197.jpg
#   inflating: celebA/img/202198.jpg
#   inflating: celebA/img/202199.jpg
#   inflating: celebA/img/202200.jpg
#   inflating: celebA/img/202201.jpg
#   inflating: celebA/img/202202.jpg
#   inflating: celebA/img/202203.jpg
#   inflating: celebA/img/202204.jpg
#   inflating: celebA/img/202205.jpg
#   inflating: celebA/img/202206.jpg
#   inflating: celebA/img/202207.jpg
#   inflating: celebA/img/202208.jpg
#   inflating: celebA/img/202209.jpg
#   inflating: celebA/img/202210.jpg
#   inflating: celebA/img/202211.jpg
#   inflating: celebA/img/202212.jpg
#   inflating: celebA/img/202213.jpg
#   inflating: celebA/img/202214.jpg
#   inflating: celebA/img/202215.jpg
#   inflating: celebA/img/202216.jpg
#   inflating: celebA/img/202217.jpg
#   inflating: celebA/img/202218.jpg
#   inflating: celebA/img/202219.jpg
#   inflating: celebA/img/202220.jpg
#   inflating: celebA/img/202221.jpg
#   inflating: celebA/img/202222.jpg
#   inflating: celebA/img/202223.jpg
#   inflating: celebA/img/202224.jpg
#   inflating: celebA/img/202225.jpg
#   inflating: celebA/img/202226.jpg
#   inflating: celebA/img/202227.jpg
#   inflating: celebA/img/202228.jpg
#   inflating: celebA/img/202229.jpg
#   inflating: celebA/img/202230.jpg
#   inflating: celebA/img/202231.jpg
#   inflating: celebA/img/202232.jpg
#   inflating: celebA/img/202233.jpg
#   inflating: celebA/img/202234.jpg
#   inflating: celebA/img/202235.jpg
#   inflating: celebA/img/202236.jpg
#   inflating: celebA/img/202237.jpg
#   inflating: celebA/img/202238.jpg
#   inflating: celebA/img/202239.jpg
#   inflating: celebA/img/202240.jpg
#   inflating: celebA/img/202241.jpg
#   inflating: celebA/img/202242.jpg
#   inflating: celebA/img/202243.jpg
#   inflating: celebA/img/202244.jpg
#   inflating: celebA/img/202245.jpg
#   inflating: celebA/img/202246.jpg
#   inflating: celebA/img/202247.jpg
#   inflating: celebA/img/202248.jpg
#   inflating: celebA/img/202249.jpg
#   inflating: celebA/img/202250.jpg
#   inflating: celebA/img/202251.jpg
#   inflating: celebA/img/202252.jpg
#   inflating: celebA/img/202253.jpg
#   inflating: celebA/img/202254.jpg
#   inflating: celebA/img/202255.jpg
#   inflating: celebA/img/202256.jpg
#   inflating: celebA/img/202257.jpg
#   inflating: celebA/img/202258.jpg
#   inflating: celebA/img/202259.jpg
#   inflating: celebA/img/202260.jpg
#   inflating: celebA/img/202261.jpg
#   inflating: celebA/img/202262.jpg
#   inflating: celebA/img/202263.jpg
#   inflating: celebA/img/202264.jpg
#   inflating: celebA/img/202265.jpg
#   inflating: celebA/img/202266.jpg
#   inflating: celebA/img/202267.jpg
#   inflating: celebA/img/202268.jpg
#   inflating: celebA/img/202269.jpg
#   inflating: celebA/img/202270.jpg
#   inflating: celebA/img/202271.jpg
#   inflating: celebA/img/202272.jpg
#   inflating: celebA/img/202273.jpg
#   inflating: celebA/img/202274.jpg
#   inflating: celebA/img/202275.jpg
#   inflating: celebA/img/202276.jpg
#   inflating: celebA/img/202277.jpg
#   inflating: celebA/img/202278.jpg
#   inflating: celebA/img/202279.jpg
#   inflating: celebA/img/202280.jpg
#   inflating: celebA/img/202281.jpg
#   inflating: celebA/img/202282.jpg
#   inflating: celebA/img/202283.jpg
#   inflating: celebA/img/202284.jpg
#   inflating: celebA/img/202285.jpg
#   inflating: celebA/img/202286.jpg
#   inflating: celebA/img/202287.jpg
#   inflating: celebA/img/202288.jpg
#   inflating: celebA/img/202289.jpg
#   inflating: celebA/img/202290.jpg
#   inflating: celebA/img/202291.jpg
#   inflating: celebA/img/202292.jpg
#   inflating: celebA/img/202293.jpg
#   inflating: celebA/img/202294.jpg
#   inflating: celebA/img/202295.jpg
#   inflating: celebA/img/202296.jpg
#   inflating: celebA/img/202297.jpg
#   inflating: celebA/img/202298.jpg
#   inflating: celebA/img/202299.jpg
#   inflating: celebA/img/202300.jpg
#   inflating: celebA/img/202301.jpg
#   inflating: celebA/img/202302.jpg
#   inflating: celebA/img/202303.jpg
#   inflating: celebA/img/202304.jpg
#   inflating: celebA/img/202305.jpg
#   inflating: celebA/img/202306.jpg
#   inflating: celebA/img/202307.jpg
#   inflating: celebA/img/202308.jpg
#   inflating: celebA/img/202309.jpg
#   inflating: celebA/img/202310.jpg
#   inflating: celebA/img/202311.jpg
#   inflating: celebA/img/202312.jpg
#   inflating: celebA/img/202313.jpg
#   inflating: celebA/img/202314.jpg
#   inflating: celebA/img/202315.jpg
#   inflating: celebA/img/202316.jpg
#   inflating: celebA/img/202317.jpg
#   inflating: celebA/img/202318.jpg
#   inflating: celebA/img/202319.jpg
#   inflating: celebA/img/202320.jpg
#   inflating: celebA/img/202321.jpg
#   inflating: celebA/img/202322.jpg
#   inflating: celebA/img/202323.jpg
#   inflating: celebA/img/202324.jpg
#   inflating: celebA/img/202325.jpg
#   inflating: celebA/img/202326.jpg
#   inflating: celebA/img/202327.jpg
#   inflating: celebA/img/202328.jpg
#   inflating: celebA/img/202329.jpg
#   inflating: celebA/img/202330.jpg
#   inflating: celebA/img/202331.jpg
#   inflating: celebA/img/202332.jpg
#   inflating: celebA/img/202333.jpg
#   inflating: celebA/img/202334.jpg
#   inflating: celebA/img/202335.jpg
#   inflating: celebA/img/202336.jpg
#   inflating: celebA/img/202337.jpg
#   inflating: celebA/img/202338.jpg
#   inflating: celebA/img/202339.jpg
#   inflating: celebA/img/202340.jpg
#   inflating: celebA/img/202341.jpg
#   inflating: celebA/img/202342.jpg
#   inflating: celebA/img/202343.jpg
#   inflating: celebA/img/202344.jpg
#   inflating: celebA/img/202345.jpg
#   inflating: celebA/img/202346.jpg
#   inflating: celebA/img/202347.jpg
#   inflating: celebA/img/202348.jpg
#   inflating: celebA/img/202349.jpg
#   inflating: celebA/img/202350.jpg
#   inflating: celebA/img/202351.jpg
#   inflating: celebA/img/202352.jpg
#   inflating: celebA/img/202353.jpg
#   inflating: celebA/img/202354.jpg
#   inflating: celebA/img/202355.jpg
#   inflating: celebA/img/202356.jpg
#   inflating: celebA/img/202357.jpg
#   inflating: celebA/img/202358.jpg
#   inflating: celebA/img/202359.jpg
#   inflating: celebA/img/202360.jpg
#   inflating: celebA/img/202361.jpg
#   inflating: celebA/img/202362.jpg
#   inflating: celebA/img/202363.jpg
#   inflating: celebA/img/202364.jpg
#   inflating: celebA/img/202365.jpg
#   inflating: celebA/img/202366.jpg
#   inflating: celebA/img/202367.jpg
#   inflating: celebA/img/202368.jpg
#   inflating: celebA/img/202369.jpg
#   inflating: celebA/img/202370.jpg
#   inflating: celebA/img/202371.jpg
#   inflating: celebA/img/202372.jpg
#   inflating: celebA/img/202373.jpg
#   inflating: celebA/img/202374.jpg
#   inflating: celebA/img/202375.jpg
#   inflating: celebA/img/202376.jpg
#   inflating: celebA/img/202377.jpg
#   inflating: celebA/img/202378.jpg
#   inflating: celebA/img/202379.jpg
#   inflating: celebA/img/202380.jpg
#   inflating: celebA/img/202381.jpg
#   inflating: celebA/img/202382.jpg
#   inflating: celebA/img/202383.jpg
#   inflating: celebA/img/202384.jpg
#   inflating: celebA/img/202385.jpg
#   inflating: celebA/img/202386.jpg
#   inflating: celebA/img/202387.jpg
#   inflating: celebA/img/202388.jpg
#   inflating: celebA/img/202389.jpg
#   inflating: celebA/img/202390.jpg
#   inflating: celebA/img/202391.jpg
#   inflating: celebA/img/202392.jpg
#   inflating: celebA/img/202393.jpg
#   inflating: celebA/img/202394.jpg
#   inflating: celebA/img/202395.jpg
#   inflating: celebA/img/202396.jpg
#   inflating: celebA/img/202397.jpg
#   inflating: celebA/img/202398.jpg
#   inflating: celebA/img/202399.jpg
#   inflating: celebA/img/202400.jpg
#   inflating: celebA/img/202401.jpg
#   inflating: celebA/img/202402.jpg
#   inflating: celebA/img/202403.jpg
#   inflating: celebA/img/202404.jpg
#   inflating: celebA/img/202405.jpg
#   inflating: celebA/img/202406.jpg
#   inflating: celebA/img/202407.jpg
#   inflating: celebA/img/202408.jpg
#   inflating: celebA/img/202409.jpg
#   inflating: celebA/img/202410.jpg
#   inflating: celebA/img/202411.jpg
#   inflating: celebA/img/202412.jpg
#   inflating: celebA/img/202413.jpg
#   inflating: celebA/img/202414.jpg
#   inflating: celebA/img/202415.jpg
#   inflating: celebA/img/202416.jpg
#   inflating: celebA/img/202417.jpg
#   inflating: celebA/img/202418.jpg
#   inflating: celebA/img/202419.jpg
#   inflating: celebA/img/202420.jpg
#   inflating: celebA/img/202421.jpg
#   inflating: celebA/img/202422.jpg
#   inflating: celebA/img/202423.jpg
#   inflating: celebA/img/202424.jpg
#   inflating: celebA/img/202425.jpg
#   inflating: celebA/img/202426.jpg
#   inflating: celebA/img/202427.jpg
#   inflating: celebA/img/202428.jpg
#   inflating: celebA/img/202429.jpg
#   inflating: celebA/img/202430.jpg
#   inflating: celebA/img/202431.jpg
#   inflating: celebA/img/202432.jpg
#   inflating: celebA/img/202433.jpg
#   inflating: celebA/img/202434.jpg
#   inflating: celebA/img/202435.jpg
#   inflating: celebA/img/202436.jpg
#   inflating: celebA/img/202437.jpg
#   inflating: celebA/img/202438.jpg
#   inflating: celebA/img/202439.jpg
#   inflating: celebA/img/202440.jpg
#   inflating: celebA/img/202441.jpg
#   inflating: celebA/img/202442.jpg
#   inflating: celebA/img/202443.jpg
#   inflating: celebA/img/202444.jpg
#   inflating: celebA/img/202445.jpg
#   inflating: celebA/img/202446.jpg
#   inflating: celebA/img/202447.jpg
#   inflating: celebA/img/202448.jpg
#   inflating: celebA/img/202449.jpg
#   inflating: celebA/img/202450.jpg
#   inflating: celebA/img/202451.jpg
#   inflating: celebA/img/202452.jpg
#   inflating: celebA/img/202453.jpg
#   inflating: celebA/img/202454.jpg
#   inflating: celebA/img/202455.jpg
#   inflating: celebA/img/202456.jpg
#   inflating: celebA/img/202457.jpg
#   inflating: celebA/img/202458.jpg
#   inflating: celebA/img/202459.jpg
#   inflating: celebA/img/202460.jpg
#   inflating: celebA/img/202461.jpg
#   inflating: celebA/img/202462.jpg
#   inflating: celebA/img/202463.jpg
#   inflating: celebA/img/202464.jpg
#   inflating: celebA/img/202465.jpg
#   inflating: celebA/img/202466.jpg
#   inflating: celebA/img/202467.jpg
#   inflating: celebA/img/202468.jpg
#   inflating: celebA/img/202469.jpg
#   inflating: celebA/img/202470.jpg
#   inflating: celebA/img/202471.jpg
#   inflating: celebA/img/202472.jpg
#   inflating: celebA/img/202473.jpg
#   inflating: celebA/img/202474.jpg
#   inflating: celebA/img/202475.jpg
#   inflating: celebA/img/202476.jpg
#   inflating: celebA/img/202477.jpg
#   inflating: celebA/img/202478.jpg
#   inflating: celebA/img/202479.jpg
#   inflating: celebA/img/202480.jpg
#   inflating: celebA/img/202481.jpg
#   inflating: celebA/img/202482.jpg
#   inflating: celebA/img/202483.jpg
#   inflating: celebA/img/202484.jpg
#   inflating: celebA/img/202485.jpg
#   inflating: celebA/img/202486.jpg
#   inflating: celebA/img/202487.jpg
#   inflating: celebA/img/202488.jpg
#   inflating: celebA/img/202489.jpg
#   inflating: celebA/img/202490.jpg
#   inflating: celebA/img/202491.jpg
#   inflating: celebA/img/202492.jpg
#   inflating: celebA/img/202493.jpg
#   inflating: celebA/img/202494.jpg
#   inflating: celebA/img/202495.jpg
#   inflating: celebA/img/202496.jpg
#   inflating: celebA/img/202497.jpg
#   inflating: celebA/img/202498.jpg
#   inflating: celebA/img/202499.jpg
#   inflating: celebA/img/202500.jpg
#   inflating: celebA/img/202501.jpg
#   inflating: celebA/img/202502.jpg
#   inflating: celebA/img/202503.jpg
#   inflating: celebA/img/202504.jpg
#   inflating: celebA/img/202505.jpg
#   inflating: celebA/img/202506.jpg
#   inflating: celebA/img/202507.jpg
#   inflating: celebA/img/202508.jpg
#   inflating: celebA/img/202509.jpg
#   inflating: celebA/img/202510.jpg
#   inflating: celebA/img/202511.jpg
#   inflating: celebA/img/202512.jpg
#   inflating: celebA/img/202513.jpg
#   inflating: celebA/img/202514.jpg
#   inflating: celebA/img/202515.jpg
#   inflating: celebA/img/202516.jpg
#   inflating: celebA/img/202517.jpg
#   inflating: celebA/img/202518.jpg
#   inflating: celebA/img/202519.jpg
#   inflating: celebA/img/202520.jpg
#   inflating: celebA/img/202521.jpg
#   inflating: celebA/img/202522.jpg
#   inflating: celebA/img/202523.jpg
#   inflating: celebA/img/202524.jpg
#   inflating: celebA/img/202525.jpg
#   inflating: celebA/img/202526.jpg
#   inflating: celebA/img/202527.jpg
#   inflating: celebA/img/202528.jpg
#   inflating: celebA/img/202529.jpg
#   inflating: celebA/img/202530.jpg
#   inflating: celebA/img/202531.jpg
#   inflating: celebA/img/202532.jpg
#   inflating: celebA/img/202533.jpg
#   inflating: celebA/img/202534.jpg
#   inflating: celebA/img/202535.jpg
#   inflating: celebA/img/202536.jpg
#   inflating: celebA/img/202537.jpg
#   inflating: celebA/img/202538.jpg
#   inflating: celebA/img/202539.jpg
#   inflating: celebA/img/202540.jpg
#   inflating: celebA/img/202541.jpg
#   inflating: celebA/img/202542.jpg
#   inflating: celebA/img/202543.jpg
#   inflating: celebA/img/202544.jpg
#   inflating: celebA/img/202545.jpg
#   inflating: celebA/img/202546.jpg
#   inflating: celebA/img/202547.jpg
#   inflating: celebA/img/202548.jpg
#   inflating: celebA/img/202549.jpg
#   inflating: celebA/img/202550.jpg
#   inflating: celebA/img/202551.jpg
#   inflating: celebA/img/202552.jpg
#   inflating: celebA/img/202553.jpg
#   inflating: celebA/img/202554.jpg
#   inflating: celebA/img/202555.jpg
#   inflating: celebA/img/202556.jpg
#   inflating: celebA/img/202557.jpg
#   inflating: celebA/img/202558.jpg
#   inflating: celebA/img/202559.jpg
#   inflating: celebA/img/202560.jpg
#   inflating: celebA/img/202561.jpg
#   inflating: celebA/img/202562.jpg
#   inflating: celebA/img/202563.jpg
#   inflating: celebA/img/202564.jpg
#   inflating: celebA/img/202565.jpg
#   inflating: celebA/img/202566.jpg
#   inflating: celebA/img/202567.jpg
#   inflating: celebA/img/202568.jpg
#   inflating: celebA/img/202569.jpg
#   inflating: celebA/img/202570.jpg
#   inflating: celebA/img/202571.jpg
#   inflating: celebA/img/202572.jpg
#   inflating: celebA/img/202573.jpg
#   inflating: celebA/img/202574.jpg
#   inflating: celebA/img/202575.jpg
#   inflating: celebA/img/202576.jpg
#   inflating: celebA/img/202577.jpg
#   inflating: celebA/img/202578.jpg
#   inflating: celebA/img/202579.jpg
#   inflating: celebA/img/202580.jpg
#   inflating: celebA/img/202581.jpg
#   inflating: celebA/img/202582.jpg
#   inflating: celebA/img/202583.jpg
#   inflating: celebA/img/202584.jpg
#   inflating: celebA/img/202585.jpg
#   inflating: celebA/img/202586.jpg
#   inflating: celebA/img/202587.jpg
#   inflating: celebA/img/202588.jpg
#   inflating: celebA/img/202589.jpg
#   inflating: celebA/img/202590.jpg
#   inflating: celebA/img/202591.jpg
#   inflating: celebA/img/202592.jpg
#   inflating: celebA/img/202593.jpg
#   inflating: celebA/img/202594.jpg
#   inflating: celebA/img/202595.jpg
#   inflating: celebA/img/202596.jpg
#   inflating: celebA/img/202597.jpg
#   inflating: celebA/img/202598.jpg
#   inflating: celebA/img/202599.jpg
#    creating: MNIST/MNIST/processed/
#   inflating: MNIST/MNIST/processed/test.pt
#   inflating: MNIST/MNIST/processed/training.pt
# replace MNIST/MNIST/raw/t10k-images-idx3-ubyte? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %% [markdown]
# ## Generative Adversarial Network (GAN)

# %% [markdown]
# > **GAN은 adversarial process, 즉 적대적 프로세스를 통해 생성 샘플을 추정하는 framework이다.**
# >
# > 1. **Generative model G**
# >   * 데이터 분포를 파악하여 샘플을 생성한다.</p>
# >   * Discriminator를 속이는 것이 학습의 목표이다.
# >   * 이는 마치 위조화폐 제작팀이라고 생각할 수 있다. 그들은 가짜 화폐를 만들어 감지되지 않으려 한다.
# >
# >
# > 2. **Discriminative model D**
# >   * 샘플이 실제 데이터셋에서 온 것인지, 생성 모델에서 온 것인지의 확률을 추정한다.</p>
# >   * Discriminative 모델은 샘플이 모델이 생성한 분포에서 왔는지, 실제 데이터 분포에서 왔는지를 판단하도록 학습한다.
# >   * 이는 마치 경찰에 비유할 수 있다. 그들은 위조 화폐를 탐지하려고 한다.
# >
# > <img src="https://drive.google.com/uc?export=view&id=19x0roNKu6up7yjOILbJq9ulgMMH7Vr3w" alt="no_image" style="width: 600px;"/>
# > <img src="https://drive.google.com/uc?export=view&id=1-9hxJROsi7Rf7lHK-rh5dTxnw39V7moJ" alt="no_image" style="width: 900px;"/>

# %% [markdown]
# ## 2. 첫 번째 실습 (GAN)
# > **1.Dataset**
# >
# >   * MNIST 데이터셋을 생성해볼 것이다.
# >   * MNIST 데이터셋은 28 X 28 이미지이다. 이 것을 784 사이즈의 벡터로 Resize 해주어야 한다.
# >
# > **2. Network**
# >   * **Generativor G**
# >     * Xavier 초기화를 사용한다.
# >       * 이전 실습에서 사용하였던 초기화 기법이다.
# >       * **nn.init.xavier_uniform_** 로 사용할 수 있다.
# >     * Latent vector Z 가 input으로 사용된다. (size=100)
# >     * hidden layer(size=128) 통과 이후에는 ReLU를 activation 함수로 사용한다.
# >     * 최종 Output layer(size=28x28) 이후에는 sigmoid를 activation 함수로 사용한다.
# >
# >
# >   * **Discriminativor D**
# >     * 마찬가지로 Xavier 초기화를 사용한다.
# >       * **nn.init.xavier_uniform_** 로 사용할 수 있다.
# >     * 입력으로 Real 데이터 또는 Fake 데이터가 사용된다.
# >     * hidden layer(size=128) 통과 이후에는 ReLU를 activation 함수로 사용한다.
# >     * 최종 Output layer(size=1) 이후에는 sigmoid를 activation 함수로 사용한다.
# >
# > **3. Loss function**
# >  * **Discriminativor D**
# >    * Real 데이터를 위해 Binary cross entropy loss(nn.BCELoss())를 이용한다.<br>
#       >   : $-{1 \over N} \sum^{N}_{i=1} y_i^{real}log(D(z_i))+(1-y_i^{real})log(1-D(z_i)) $ <br>
# >    * Fake 데이터도 마찬가지로 Binary cross entropy loss(nn.BCELoss())를 이용한다. <br>
#       >   : $-{1 \over N} \sum^{N}_{i=1} y_i^{fake}log(D(G(z_i)))+(1-y_i^{fake})log(1-D(G(z_i)))$ <br>
# >    * $y_i^{real}=1, y_i^{fake}=0$  이다.
# >
# >
# >  * **Generativor G**
# >    * Real 데이터에 대해 (사실 이 Real 데이터는 fake이다.) Binary cross entropy loss(nn.BCELoss())를 이용한다. G의 목표는 fake 데이터인 $G(z_i)$를 Real로 속이는 것이기 때문이다.
# >
# >    $-{1 \over N} \sum^{N}_{i=1} y_i^{real}log(D(G(z_i)))+(1-y_i^{real})log(1-D(G(z_i))) $ <br>
# >
# >    ($y_i^{real}=1$)
# >
# >
# > **4. Training**
# >    * 논문에서 제공한 알고리즘은 다음과 같다.
# >
# >
# > <img src="https://drive.google.com/uc?export=view&id=15-eHmFSVCM_Aca-MTdefqZcwgKk-TKKt" alt="no_image" style="width: 600px;"/><br>
# >
# >    * 생성모델 G와 판별모델 D를 교대로 훈련시킨다.
# >    * D의 매개변수가 업데이트될 때 G의 역전파가 차단된다.

# %% [markdown]
# ## 실습 시작

# %%
import random
import torch
import torch.nn as nn
import torch.utils.data
import torchvision
import torchvision.datasets as dset
import torchvision.transforms as transforms
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import os
import os.path as osp

# %matplotlib inline

# %%
# Data path
PATH = "/content/MNIST/"

# Batch size
bs = 256

# image size
img_size = 28

# latent vector z의 size
z_size = 100

# training epochs
num_epochs = 500

# Learning rate
lr = 0.001

# Beta1 hyperparameter(for Adam)
beta1 = 0.5

# Real or Fake label
real_label = 1
fake_label = 0

# %% [markdown]
# ### Dataset loading & Data Loader

# %%
train_dataset = dset.MNIST(root=PATH,
                           train=True,
                           transform=transforms.ToTensor(),
                           download=True)

data_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                          batch_size=bs,
                                          shuffle=True,
                                          drop_last=True)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to /content/MNIST/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:01<00:00, 5111059.77it/s]
# Extracting /content/MNIST/MNIST/raw/train-images-idx3-ubyte.gz to /content/MNIST/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to /content/MNIST/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 66127.23it/s]
# Extracting /content/MNIST/MNIST/raw/train-labels-idx1-ubyte.gz to /content/MNIST/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to /content/MNIST/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:01<00:00, 1267573.08it/s]
# Extracting /content/MNIST/MNIST/raw/t10k-images-idx3-ubyte.gz to /content/MNIST/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to /content/MNIST/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 6179217.89it/s]
# Extracting /content/MNIST/MNIST/raw/t10k-labels-idx1-ubyte.gz to /content/MNIST/MNIST/raw

# %% [markdown]
# ### Generative model G

# %%
# Generator's hidden layer size (Channels of generator feature) : 128
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        # 여기에 코드 작성
        self.linear1 = nn.Linear(z_size, 128)
        self.linear2 = nn.Linear(128, img_size * img_size)
        self.relu = nn.ReLU()
        self.sigmoid = nn.Sigmoid()

        # Initialize weight parameters
        nn.init.xavier_uniform_(self.linear1.weight)
        nn.init.xavier_uniform_(self.linear2.weight)

    def forward(self, x):
        # 여기에 코드 작성
        x = self.linear1(x)
        x = self.relu(x)
        x = self.linear2(x)
        x = self.sigmoid(x)

        return x

# %% [markdown]
# ### Discriminative model D

# %%
# Discriminator's hidden layer size (Channels of discriminator feature) : 128
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        # 여기에 코드 작성
        self.linear1 = nn.Linear(img_size  * img_size, 128)
        self.linear2 = nn.Linear(128, 1)
        self.relu = nn.ReLU()
        self.sigmoid = nn.Sigmoid()

        # Initialize weight parameters
        nn.init.xavier_uniform_(self.linear1.weight)
        nn.init.xavier_uniform_(self.linear2.weight)

    def forward(self, x):
        # 여기에 코드 작성
        x = self.linear1(x)
        x = self.relu(x)
        x = self.linear2(x)
        x = self.sigmoid(x)

        return x

# %%
model_G = Generator()
model_D = Discriminator()

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model_G.to(device)
model_D.to(device)
print(model_G)
print(model_D)
# Out:
# Generator(
#   (linear1): Linear(in_features=100, out_features=128, bias=True)
#   (linear2): Linear(in_features=128, out_features=784, bias=True)
#   (relu): ReLU()
#   (sigmoid): Sigmoid()
# )
# Discriminator(
#   (linear1): Linear(in_features=784, out_features=128, bias=True)
#   (linear2): Linear(in_features=128, out_features=1, bias=True)
#   (relu): ReLU()
#   (sigmoid): Sigmoid()
# )

# %% [markdown]
# ### Loss function & optimizer(Adam)

# %%
criterion = nn.BCELoss()

optimizer_G = torch.optim.Adam(model_G.parameters(), lr=lr, betas=(beta1, 0.999))
optimizer_D = torch.optim.Adam(model_D.parameters(), lr=lr, betas=(beta1, 0.999))

# %% [markdown]
# ### function for visualizing picture

# %%
def plot(samples):
    fig = plt.figure(figsize=(4, 4))
    gs = gridspec.GridSpec(4, 4)
    gs.update(wspace=0.05, hspace=0.05)
    for i, sample in enumerate(samples):
        ax = plt.subplot(gs[i])
        plt.axis('off')
        ax.set_xticklabels([])
        ax.set_yticklabels([])
        ax.set_aspect('equal')
        plt.imshow(sample.reshape(28, 28), cmap='Greys_r')
    return fig

# %% [markdown]
# ### Training GAN
# * 모델 G와 D를 교대로 훈련시킨다
# * **back-*propagation을* 차단하려면 "output.detach()"를 사용하면 된다.**
# * 10 epoch마다 loss를 출력한다.
# * 50 epoch마다 생성된 이미지를 plot 한다. (1 epoch에서부터 시작)
# * 학습이 진행됨에 따라 이미지의 퀄리티가 어떻게 변경되는지 확인한다.
# * train loop만 작성하면 되며, loss 출력 및 생성 이미지 plot하는 과정은 작성해두었다.(수정하지 말것!)

# %%
# label for real & fake data
label_real = torch.full((bs,), real_label, device=device, dtype=torch.float)
label_fake = torch.full((bs,), fake_label, device=device, dtype=torch.float)

#  Noise
fixed_noise = torch.randn(bs, z_size, device=device, dtype=torch.float)

for epoch in range(num_epochs):

    model_G.train()
    model_D.train()

    for i, data in enumerate(data_loader):

        data = data[0].to(device)
        data = data.view(bs, -1)
        # (조건 1) Discriminator의 loss의 변수명은 err_D로 한다.
        # (조건 2) Generator의 loss의 변수명은 err_G로 한다.
        # 판별자 학습
        model_D.zero_grad()

        # 실제 데이터에 대한 판별자 손실
        output_real = model_D(data).view(-1)
        loss_real = criterion(output_real, label_real)
        loss_real.backward()


        # 생성된 데이터에 대한 판별자 손실
        noise = torch.randn(bs, z_size).to(device)
        fake_images = model_G(noise)
        label_fake.fill_(fake_label)

        output_fake = model_D(fake_images.detach()).view(-1)
        loss_fake = criterion(output_fake, label_fake)
        loss_fake.backward()

        # 판별자 총 손실 및 역전파
        err_D = loss_real + loss_fake
        optimizer_D.step()

        # 생성자 학습
        model_G.zero_grad()
        label_real.fill_(real_label)

        # 생성된 데이터에 대한 생성자 손실
        output_fake = model_D(fake_images).view(-1)
        err_G = criterion(output_fake, label_real)

        # 생성자 손실 및 역전파
        err_G.backward()
        optimizer_G.step()



    # Output training stats
    if (epoch+1) % 10 == 0:
        print('[%d/%d][%d/%d]\tLoss_D: %.4f\tLoss_G: %.4f'
              % ((epoch+1), num_epochs, i+1, len(data_loader), err_D.item(), err_G.item()))

    if (epoch) % 50 == 0:
        model_G.eval()
        model_D.eval()
        output = model_G(fixed_noise).detach().cpu().numpy()
        fig = plot(output[:16])
# Out:
# [10/500][234/234]	Loss_D: 0.3880	Loss_G: 3.3838
# [20/500][234/234]	Loss_D: 0.8933	Loss_G: 2.2123
# [30/500][234/234]	Loss_D: 0.0901	Loss_G: 5.3802
# [40/500][234/234]	Loss_D: 0.0504	Loss_G: 6.2812
# [50/500][234/234]	Loss_D: 0.0478	Loss_G: 6.4051
# [60/500][234/234]	Loss_D: 0.1452	Loss_G: 4.5582
# [70/500][234/234]	Loss_D: 1.1228	Loss_G: 3.0310
# [80/500][234/234]	Loss_D: 1.1012	Loss_G: 1.5998
# [90/500][234/234]	Loss_D: 1.1467	Loss_G: 2.5848
# [100/500][234/234]	Loss_D: 1.1770	Loss_G: 1.1057
# [110/500][234/234]	Loss_D: 1.0854	Loss_G: 2.5232
# [120/500][234/234]	Loss_D: 1.2172	Loss_G: 2.2538
# [130/500][234/234]	Loss_D: 0.8701	Loss_G: 2.1267
# [140/500][234/234]	Loss_D: 0.8819	Loss_G: 1.5572
# [150/500][234/234]	Loss_D: 0.8829	Loss_G: 2.2857
# [160/500][234/234]	Loss_D: 0.8627	Loss_G: 1.5678
# [170/500][234/234]	Loss_D: 0.7993	Loss_G: 1.9466
# [180/500][234/234]	Loss_D: 1.1385	Loss_G: 1.0043
# [190/500][234/234]	Loss_D: 0.9285	Loss_G: 1.3254
# [200/500][234/234]	Loss_D: 0.8360	Loss_G: 1.7661
# [210/500][234/234]	Loss_D: 0.9017	Loss_G: 1.5427
# [220/500][234/234]	Loss_D: 0.7431	Loss_G: 1.8072
# [230/500][234/234]	Loss_D: 0.8244	Loss_G: 2.3302
# [240/500][234/234]	Loss_D: 0.7798	Loss_G: 1.5469
# [250/500][234/234]	Loss_D: 0.7444	Loss_G: 1.7463
# [260/500][234/234]	Loss_D: 0.7244	Loss_G: 2.6889
# [270/500][234/234]	Loss_D: 0.6854	Loss_G: 1.8831
# [280/500][234/234]	Loss_D: 0.6588	Loss_G: 2.1463
# [290/500][234/234]	Loss_D: 0.7267	Loss_G: 1.7810
# [300/500][234/234]	Loss_D: 0.6398	Loss_G: 1.8632
# [310/500][234/234]	Loss_D: 0.7702	Loss_G: 2.0483
# [320/500][234/234]	Loss_D: 0.7042	Loss_G: 2.6206
# [330/500][234/234]	Loss_D: 0.7338	Loss_G: 2.5039
# [340/500][234/234]	Loss_D: 0.6638	Loss_G: 2.5093
# [350/500][234/234]	Loss_D: 0.6803	Loss_G: 2.0286
# [360/500][234/234]	Loss_D: 0.5637	Loss_G: 2.3144
# [370/500][234/234]	Loss_D: 0.7620	Loss_G: 1.8018
# [380/500][234/234]	Loss_D: 0.6956	Loss_G: 1.7229
# [390/500][234/234]	Loss_D: 0.7513	Loss_G: 1.6409
# [400/500][234/234]	Loss_D: 0.6647	Loss_G: 2.3298
# [410/500][234/234]	Loss_D: 0.7531	Loss_G: 2.4319
# [420/500][234/234]	Loss_D: 0.6891	Loss_G: 2.4522
# [430/500][234/234]	Loss_D: 0.7977	Loss_G: 2.5701
# [440/500][234/234]	Loss_D: 0.6641	Loss_G: 2.5831
# [450/500][234/234]	Loss_D: 0.6145	Loss_G: 1.8795
# [460/500][234/234]	Loss_D: 0.5950	Loss_G: 2.6080
# [470/500][234/234]	Loss_D: 0.6335	Loss_G: 2.4475
# [480/500][234/234]	Loss_D: 0.6579	Loss_G: 1.9083
# [490/500][234/234]	Loss_D: 0.6219	Loss_G: 2.2542
# [500/500][234/234]	Loss_D: 0.6154	Loss_G: 2.0283

# %% [markdown]
# ## 2. DCGAN (Deep Convolutional GANs)
# > **1. Dataset**
# >
# >   * CelebA dataset
# >   * Resize to (64, 64)
# >
# > **2. Network**
# >
# >
# >   * **가이드라인**
# >      * Generator와 Discriminator에서는 pooling layer를 사용하지 않는다.
# >      * Generator와 Discriminator에서는 FCN을 사용하지 않는다.
# >      * Generator와 Discriminator 모두 마지막 layer를 제외한 모든 layer에 Batch normalization을 사용한다.
# >      * Generator에서는 마지막 layer를 제외한 모든 layer의 activation function으로 ReLU를 사용한다. 마지막 layer에서는 Tanh를 사용한다.
# >      * Discriminator에서는 모든 layer의 activation function으로 LeakyReLU를 사용한다.
# >
# >
# >
# >   * **Generativor G**
# >     * Xavier 초기화를 사용한다.
# >       * **nn.init.xavier_uniform_** 로 사용할 수 있다.
# >       (실제 논문에서는 다른 초기화 기법을 사용했지만 Xavier 초기화로도 성능이 잘 나온다.)
# >     * Latent vector Z 가 input으로 사용된다. (size=100)
# >       (Upconvolution으로 size를 (bs, 100, 1, 1)으로 바꿔주어야 한다.)
# >     * 논문에서는 Upconvolution의 stride를 5로 했지만 우리 실습에서는 4로 한다.
# >     * 마지막 layer를 제외한 모든 layer에 Batch normalization을 사용한다.
#
# >   * **Discriminativor D**
# >     * 마찬가지로 Xavier 초기화를 사용한다.
# >       * **nn.init.xavier_uniform_** 로 사용할 수 있다.
# >     * 입력으로 Real 데이터 또는 Fake 데이터가 사용된다. (size=64x64)
# >     * 구조는 upconvolution이 convolution으로 대체되고 마지막 출력 크기가 (bs, 1, 1, 1)로 변경되는 Generativor G의 반대 버전입니다.
# >     * 마지막 layer를 제외한 모든 layer에 Batch normalization을 사용한다.
#
#
# > **3. Loss function**
# >  * **Discriminativor D**
# >    * Real 데이터를 위해 Binary cross entropy loss(nn.BCELoss())를 이용한다.<br>
#       >   : $-{1 \over N} \sum^{N}_{i=1} y_i^{real}log(D(z_i))+(1-y_i^{real})log(1-D(z_i)) $ <br>
# >    * Fake 데이터도 마찬가지로 Binary cross entropy loss(nn.BCELoss())를 이용한다. <br>
#       >   : $-{1 \over N} \sum^{N}_{i=1} y_i^{fake}log(D(G(z_i)))+(1-y_i^{fake})log(1-D(G(z_i)))$ <br>
# >    * $y_i^{real}=1, y_i^{fake}=0$  이다.
# >
# >
# >  * **Generativor G**
# >    * Real 데이터에 대해 (사실 이 Real 데이터는 fake이다.) Binary cross entropy loss(nn.BCELoss())를 이용한다. G의 목표는 fake 데이터인 $G(z_i)$를 Real로 속이는 것이기 때문이다.
# >
# >    $-{1 \over N} \sum^{N}_{i=1} y_i^{real}log(D(G(z_i)))+(1-y_i^{real})log(1-D(G(z_i))) $ <br>
# >
# >    ($y_i^{real}=1$)
#
# >
# > **4. Training Strategy**
# >    * GAN을 훈련시키는 알고리즘과 동일하다.
# >    * 생성모델 G와 판별모델 D를 교대로 훈련시킨다.
# >    * D의 매개변수가 업데이트될 때 G의 역전파가 차단된다.

# %% [markdown]
# # 실습 시작

# %%
import os
import random
import torch
import torch.nn as nn
import torch.nn.parallel
import torch.utils.data
import torchvision
import torchvision.datasets as dset
import torchvision.transforms as transforms
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import os
import os.path as osp

# %matplotlib inline

# %%
# Data path
PATH = '/content/celebA/'

# Batch size
bs = 128

# image size
img_size = 64

# latent vector z의 size
z_size = 100

# training epochs
num_epochs = 8

# Learning rate
lr = 0.0002

# Beta1 hyperparameter(for Adam)
beta1 = 0.5

# Real or Fake label
real_label = 1
fake_label = 0

# %% [markdown]
# ### Dataset loading & Data Loader

# %%
transform = transforms.Compose([
    transforms.Resize(img_size),
    transforms.CenterCrop(img_size),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

dataset = dset.ImageFolder(root=PATH,
                           transform=transform)

data_loader = torch.utils.data.DataLoader(dataset=dataset,
                                           batch_size=bs,
                                           shuffle=True,
                                           drop_last=True)

# %% [markdown]
# ### celebA의 데이터셋을 몇 개만 확인해보자

# %%
def imshow(inp, title=None):
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.5, 0.5, 0.5])
    std = np.array([0.5, 0.5, 0.5])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)

data_loader_sample = torch.utils.data.DataLoader(dataset=dataset,
                                                 batch_size=4,
                                                 shuffle=True)
inputs, classes = next(iter(data_loader_sample))
out = torchvision.utils.make_grid(inputs)
imshow(out)

# %% [markdown]
# ### Generative model G
# * 'ReLU', 'LeakyReLU', 'Tanh', 'Sigmoid' 중에서 적절한 activation function을
# 사용하자.
# * **upconv2d** 와 **BatchNorm**을 이용하자.
# * 6차 강의 실습과 7차 강의 실습를 복습해보면 도움을 받을 수 있을 것이다.
# * 또한, Pytorch 공식 홈페이지를 검색해보는 등 다양한 자료를 참고해보자.

# %%
# Generator's hidden layer size (Channels of generator feature) : 64

class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()

        self.upconv2d1 = nn.ConvTranspose2d( z_size, img_size * 8, 4, 1, 0, bias=False)
        self.upconv2d2 = nn.ConvTranspose2d(img_size * 8, img_size * 4, 4, 2, 1, bias=False)
        self.upconv2d3 = nn.ConvTranspose2d( img_size * 4, img_size * 2, 4, 2, 1, bias=False)
        self.upconv2d4 = nn.ConvTranspose2d( img_size * 2, img_size, 4, 2, 1, bias=False)
        self.upconv2d5 = nn.ConvTranspose2d( img_size, 3, 4, 2, 1, bias=False)
        self.BatchNorm1 = nn.BatchNorm2d(img_size * 8)
        self.BatchNorm2 = nn.BatchNorm2d(img_size * 4)
        self.BatchNorm3 = nn.BatchNorm2d(img_size * 2)
        self.BatchNorm4 = nn.BatchNorm2d(img_size)
        self.relu = nn.ReLU()
        self.tanh = nn.Tanh()

        nn.init.xavier_uniform_(self.upconv2d1.weight)
        nn.init.xavier_uniform_(self.upconv2d2.weight)
        nn.init.xavier_uniform_(self.upconv2d3.weight)
        nn.init.xavier_uniform_(self.upconv2d4.weight)
        nn.init.xavier_uniform_(self.upconv2d5.weight)

    def forward(self, x):
      x = self.upconv2d1(x)
      x = self.BatchNorm1(x)
      x = self.relu(x)

      x = self.upconv2d2(x)
      x = self.BatchNorm2(x)
      x = self.relu(x)

      x = self.upconv2d3(x)
      x = self.BatchNorm3(x)
      x = self.relu(x)

      x = self.upconv2d4(x)
      x = self.BatchNorm4(x)
      x = self.relu(x)

      x = self.upconv2d5(x)
      x = self.tanh(x)

      return x

# %% [markdown]
# ### Discriminative model D
# * 'ReLU', 'LeakyReLU', 'Tanh', 'Sigmoid' 중에서 적절한 activation function을
# 사용하자.
# * **conv2d** 와 **BatchNorm**을 이용하자.
# * 6차 강의 실습과 7차 강의 실습를 복습해보면 도움을 받을 수 있을 것이다.
# * 또한, Pytorch 공식 홈페이지를 검색해보는 등 다양한 자료를 참고해보자.

# %%
# Discriminator's hidden layer size (Channels of discriminator feature) : 64

class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()

        self.conv2d1 = nn.Conv2d(3, img_size, 4, 2, 1, bias=False)
        self.conv2d2 = nn.Conv2d(img_size, img_size * 2, 4, 2, 1, bias=False)
        self.conv2d3 = nn.Conv2d(img_size * 2, img_size * 4, 4, 2, 1, bias=False)
        self.conv2d4 = nn.Conv2d(img_size * 4, img_size * 8, 4, 2, 1, bias=False)
        self.conv2d5 = nn.Conv2d(img_size * 8, 1, 4, 1, 0, bias=False)
        self.BatchNorm1 = nn.BatchNorm2d(img_size * 2)
        self.BatchNorm2 = nn.BatchNorm2d(img_size * 4)
        self.BatchNorm3 = nn.BatchNorm2d(img_size * 8)
        self.leakyrelu = nn.LeakyReLU(0.2, inplace=True)
        self.sigmoid = nn.Sigmoid()

        nn.init.xavier_uniform_(self.conv2d1.weight)
        nn.init.xavier_uniform_(self.conv2d2.weight)
        nn.init.xavier_uniform_(self.conv2d3.weight)
        nn.init.xavier_uniform_(self.conv2d4.weight)
        nn.init.xavier_uniform_(self.conv2d5.weight)

    def forward(self, x):
      x = self.conv2d1(x)
      x = self.leakyrelu(x)

      x = self.conv2d2(x)
      x = self.BatchNorm1(x)
      x = self.leakyrelu(x)

      x = self.conv2d3(x)
      x = self.BatchNorm2(x)
      x = self.leakyrelu(x)

      x = self.conv2d4(x)
      x = self.BatchNorm3(x)
      x = self.leakyrelu(x)

      x = self.conv2d5(x)
      x = self.sigmoid(x)

      return x

# %%
model_G = Generator()
model_D = Discriminator()

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model_G.to(device)
model_D.to(device)
print(model_G)
print(model_D)
# Out:
# Generator(
#   (upconv2d1): ConvTranspose2d(100, 512, kernel_size=(4, 4), stride=(1, 1), bias=False)
#   (upconv2d2): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (upconv2d3): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (upconv2d4): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (upconv2d5): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (BatchNorm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (BatchNorm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (BatchNorm3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (BatchNorm4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU()
#   (tanh): Tanh()
# )
# Discriminator(
#   (conv2d1): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (conv2d2): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (conv2d3): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (conv2d4): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (conv2d5): Conv2d(512, 1, kernel_size=(4, 4), stride=(1, 1), bias=False)
#   (BatchNorm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (BatchNorm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (BatchNorm3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (leakyrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#   (sigmoid): Sigmoid()
# )

# %% [markdown]
# ### Loss function & optimizer(Adam)

# %%
criterion = nn.BCELoss()

optimizer_G = torch.optim.Adam(model_G.parameters(), lr=lr, betas=(beta1, 0.999))
optimizer_D = torch.optim.Adam(model_D.parameters(), lr=lr, betas=(beta1, 0.999))

# %% [markdown]
# gfdgdfhggfg
# ### function for visualizing picture

# %%
def plot(samples):
    fig = plt.figure(figsize=(4, 4))
    gs = gridspec.GridSpec(4, 4)
    gs.update(wspace=0.05, hspace=0.05)
    for i, sample in enumerate(samples):
        ax = plt.subplot(gs[i])
        plt.axis('off')
        ax.set_xticklabels([])
        ax.set_yticklabels([])
        ax.set_aspect('equal')
        plt.imshow(sample.reshape(64, 64, 3), cmap='Greys_r')
    return fig

# %% [markdown]
# ### Training GAN
# * 모델 G와 D를 교대로 훈련시킨다
# * **back-*propagation을* 차단하려면 "output.detach()"를 사용하면 된다.**
# * 학습이 완료된 후, 생성된 이미지 샘플을 확인해보자.
# * train loop만 작성하면 되며, loss 출력 및 생성 이미지 plot하는 과정은 작성해두었다.(수정하지 말것!)

# %%
label_real = torch.full((bs,), real_label, device=device, dtype=torch.float)
label_fake = torch.full((bs,), fake_label, device=device, dtype=torch.float)

#  The input noise for inference
fixed_noise = torch.randn(bs, z_size, 1, 1, device=device, dtype=torch.float)


for epoch in range(num_epochs):

    model_G.train()
    model_D.train()

    for i, data in enumerate(data_loader):

        data = data[0].to(device)

        ### 여기에 코드 작성
        # (조건 1) Discriminator의 loss의 변수명은 err_D로 한다.
        # (조건 2) Generator의 loss의 변수명은 err_G로 한다.
        model_D.zero_grad()

        # 배치들의 사이즈나 사용할 디바이스에 맞게 조정합니다
        b_size = data.size(0)

        # 진짜 데이터들로 이루어진 배치를 D에 통과시킵니다
        output = model_D(data).view(-1)

        # 손실값을 구합니다
        errD_real = criterion(output, label_real)

        # 역전파의 과정에서 변화도를 계산합니다
        errD_real.backward()
        D_x = output.mean().item()

        ## 가짜 데이터들로 학습을 합니다
        # 생성자에 사용할 잠재공간 벡터를 생성합니다
        noise = torch.randn(b_size, z_size, 1, 1, device=device)

        # G를 이용해 가짜 이미지를 생성합니다
        fake = model_G(noise)
        label_fake.fill_(fake_label)

        # D를 이용해 데이터의 진위를 판별합니다
        output = model_D(fake.detach()).view(-1)
        # D의 손실값을 계산합니다
        errD_fake = criterion(output, label_fake)

        # 역전파를 통해 변화도를 계산합니다. 이때 앞서 구한 변화도에 더합니다(accumulate)
        errD_fake.backward()


        # 가짜 이미지와 진짜 이미지 모두에서 구한 손실값들을 더합니다
        # 이때 errD는 역전파에서 사용되지 않고, 이후 학습 상태를 리포팅(reporting)할 때 사용합니다
        err_D = errD_real + errD_fake
        # D를 업데이트 합니다
        optimizer_D.step()

        ############################
        # (2) G 신경망을 업데이트 합니다: log(D(G(z)))를 최대화 합니다
        ###########################
        model_G.zero_grad()
        label_real.fill_(real_label)  # 생성자의 손실값을 구하기 위해 진짜 라벨을 이용할 겁니다
        # 우리는 방금 D를 업데이트했기 때문에, D에 다시 가짜 데이터를 통과시킵니다.
        # 이때 G는 업데이트되지 않았지만, D가 업데이트 되었기 때문에 앞선 손실값가 다른 값이 나오게 됩니다
        output = model_D(fake).view(-1)
        # G의 손실값을 구합니다
        err_G = criterion(output, label_real)
        # G의 변화도를 계산합니다
        err_G.backward()
        # G를 업데이트 합니다
        optimizer_G.step()


        # Output training stats
        if i % 400 == 0 and i != 0:
            print('[%d/%d][%d/%d]\tLoss_D: %.4f\tLoss_G: %.4f\t'
                  % (epoch, num_epochs, i, len(data_loader),
                     err_D.item(), err_G.item()))

            model_G.eval()
            model_D.eval()
            with torch.no_grad():
                output = model_G(fixed_noise).detach().cpu().numpy()
                output = np.transpose((output+1)/2, (0, 2, 3, 1))
                fig = plot(output[:16])

            model_G.train()
            model_D.train()
# Out:
# Output hidden; open in https://colab.research.google.com to view.
