# %%
# !pip install -q -U google-generativeai

# %%
import pathlib
import textwrap

import google.generativeai as genai

GOOGLE_API_KEY="AIzaSyBRJmwgBGl2li_RjCQ2bmZbwsdWx1elzYI"

genai.configure(api_key=GOOGLE_API_KEY)

# %% [markdown]
# # How to use

# %%
model = genai.GenerativeModel('gemini-pro')
response = model.generate_content("Tell me about Newton's second law.")
print(response.text)
# Out:
# **Newton's Second Law of Motion**
#
# **Statement:**
#
# > The acceleration of an object is directly proportional to the net force acting on the object and inversely proportional to the object's mass.
#
# **Formula:**
#
# ```
# F = ma
# ```
#
# Where:
#
# * **F** is the net force acting on the object (in newtons, N)
# * **m** is the mass of the object (in kilograms, kg)
# * **a** is the acceleration of the object (in meters per second squared, m/s²)
#
# **Key Points:**
#
# * The greater the force applied to an object, the greater its acceleration.
# * The heavier an object is (greater mass), the less it will accelerate for a given force.
# * The direction of the acceleration is the same as the direction of the net force.
#
# **Applications:**
#
# Newton's second law has numerous applications in physics and engineering, including:
#
# * **Calculating the force required to move an object:** F = ma
# * **Predicting the motion of objects:** a = F/m
# * **Determining the mass of an object:** m = F/a
# * **Engineering design:** Designing structures and machines that withstand forces and accelerate effectively
# * **Transportation:** Understanding the forces involved in vehicle movement and acceleration
# * **Sports:** Analyzing the forces at play in various sports activities
#
# **Examples:**
#
# * When you push a shopping cart with a force of 50 N and it accelerates at 2 m/s², the cart has a mass of 25 kg (F = ma = 50 N = 25 kg * 2 m/s²).
# * A falling apple accelerates downward at 9.8 m/s² because of the gravitational force pulling it towards the Earth.
# * A rocket accelerates upward when it burns fuel and expels exhaust, creating a thrust force that exceeds its weight (F = ma).

# %% [markdown]
# # 역할 부여하기

# %%
model = genai.GenerativeModel('gemini-pro')
instruction = "You are an elementary school physics teacher."
prompt = "Tell me about Newton's second law."

# %%
# 전체 프롬프트 생성 (instruction 포함)
full_prompt = f"{instruction}\n{prompt}"
# 모델 호출
response = model.generate_content(full_prompt)

# %%
print(response.text)
# Out:
# **Newton's Second Law of Motion**
#
# "The acceleration of an object as produced by a net force is directly proportional to the magnitude of the net force, in the same direction as the net force, and inversely proportional to the mass of the object."
#
# **Formula:**
#
# ```
# F = m * a
# ```
#
# Where:
#
# * **F** is the net force acting on the object (in Newtons)
# * **m** is the mass of the object (in kilograms)
# * **a** is the acceleration of the object (in meters per second squared)
#
# **Key Concepts:**
#
# * **Net Force:** The total force acting on an object after accounting for all forces in different directions.
# * **Acceleration:** The rate at which an object changes its velocity.
# * **Mass:** The measure of an object's resistance to acceleration.
#
# **Implications:**
#
# * **Direct Proportionality to Force:** The greater the net force, the greater the acceleration.
# * **Inverse Proportionality to Mass:** The greater the mass, the less the acceleration for the same force.
# * **Newton's Law of Universal Gravitation:** A special case of Newton's second law that describes the gravitational force between objects.
#
# **Applications in Everyday Life:**
#
# * **Pushing a toy car:** The force you apply to the car causes it to accelerate.
# * **Swinging:** The force of your legs pushing off creates an acceleration, causing the swing to move.
# * **Walking:** The force of your legs against the ground creates an acceleration, propelling you forward.
#
# **Classroom Activities to Demonstrate Newton's Second Law:**
#
# * **Mass and Acceleration Race:** Time students pushing objects of different masses to determine how mass affects acceleration.
# * **Force and Acceleration Graphs:** Have students plot graphs showing the relationship between force and acceleration using springs or pulleys.
# * **Rocket Car Experiment:** Design and build rockets with different masses and launch them, measuring their acceleration and calculating the force using Newton's second law.

# %% [markdown]
# # Instruction 추가하기

# %%
instruction = "You must explain the concept with example problems."
prompt = "Tell me about Newton's second law."

# %%
model = genai.GenerativeModel('gemini-pro')
# 전체 프롬프트 생성 (instruction 포함)
full_prompt = f"{instruction}\n{prompt}"
# 모델 호출
response = model.generate_content(full_prompt)

# %%
print(response.text)
# Out:
# **Newton's Second Law of Motion**
#
# Newton's second law states that the acceleration of an object is directly proportional to the net force acting on the object and inversely proportional to the object's mass. Mathematically, it can be expressed as:
#
# ```
# F = ma
# ```
#
# where:
#
# * F is the net force acting on the object (in Newtons)
# * m is the mass of the object (in kilograms)
# * a is the acceleration of the object (in meters per second squared)
#
# **Example Problems**
#
# **Problem 1:**
#
# A force of 100 N is applied to a 20 kg object. What is the acceleration of the object?
#
# **Solution:**
#
# F = ma
# 100 N = 20 kg * a
# a = 100 N / 20 kg
# **a = 5 m/s²**
#
# **Problem 2:**
#
# A 50 kg object is moving with a constant velocity of 10 m/s. What is the net force acting on the object?
#
# **Solution:**
#
# F = ma
# Since the object is moving with constant velocity, its acceleration is zero.
# Therefore, F = 0 N
# **F = 0 N**
#
# **Problem 3:**
#
# A 100 N force is applied to a 50 kg object that is initially at rest. The coefficient of friction between the object and the surface is 0.2. What is the acceleration of the object?
#
# **Solution:**
#
# F = ma
# F = 100 N
# m = 50 kg
# a = ?
#
# The force of friction is:
#
# Ff = μ * Fn
# Ff = 0.2 * 98 N (the normal force is equal to the weight of the object)
# Ff = 19.6 N
#
# The net force is:
#
# Fnet = F - Ff
# Fnet = 100 N - 19.6 N
# **Fnet = 80.4 N**
#
# Therefore, the acceleration is:
#
# Fnet = ma
# 80.4 N = 50 kg * a
# **a = 1.61 m/s²**

# %% [markdown]
# # 할루시네이션

# %%
model = genai.GenerativeModel('gemini-pro')
response = model.generate_content("Use the four basic operations (+, -, /, *) to appropriately operate 4, 9, 10, 13 to make 24.")
print(response.text)
# Out:
# (10 + 4) * (9 / 3) = 24

# %% [markdown]
# # Few shot Prompting

# %%
prompt = """
The movie was good // positive
The movie was quite bad // negative
I really like the movie, but the ending was lacking // neutral
I loved the movie //
"""

# %%
model = genai.GenerativeModel('gemini-pro')
# 전체 프롬프트 생성 (instruction 포함)
response = model.generate_content(prompt)

# %%
print(response.text)
# Out:
# positive

# %% [markdown]
# # 추론 task에서는 소용이 없다...

# %%
model = genai.GenerativeModel('gemini-pro')
response = model.generate_content("Is that True? : The odd numbers in 15, 32, 5, 13, 82, 7, 1 add up to an even number.")
print(response.text)
# Out:
# False

# %%
model = genai.GenerativeModel('gemini-pro')
#프롬프트
prompt = """
The odd numbers in this group add up to an even number: 4, 8, 9, 15, 12, 2, 1.
A: The answer is False.
The odd numbers in this group add up to an even number: 17,  10, 19, 4, 8, 12, 24.
A: The answer is True.
The odd numbers in this group add up to an even number: 16,  11, 14, 4, 8, 13, 24.
A: The answer is True.
The odd numbers in this group add up to an even number: 17,  9, 10, 12, 13, 4, 2.
A: The answer is False.
The odd numbers in this group add up to an even number: 15, 32, 5, 13, 82, 7, 1.
A:
"""
# 모델 호출
response = model.generate_content(prompt)
print(response.text)
# Out:
# The answer is False.

# %% [markdown]
# # Chain of Thought

# %%
instruction = "Let's think step by step. Explain about your thought."
prompt = """
The odd numbers in this group add up to an even number: 4, 8, 9, 15, 12, 2, 1.
A: The answer is False.
The odd numbers in this group add up to an even number: 17,  10, 19, 4, 8, 12, 24.
A: The answer is True.
The odd numbers in this group add up to an even number: 16,  11, 14, 4, 8, 13, 24.
A: The answer is True.
The odd numbers in this group add up to an even number: 17,  9, 10, 12, 13, 4, 2.
A: The answer is False.
The odd numbers in this group add up to an even number: 15, 32, 5, 13, 82, 7, 1.
A:
"""

# %%
model = genai.GenerativeModel('gemini-pro')
# 전체 프롬프트 생성 (instruction 포함)
full_prompt = f"{instruction}\n{prompt}"
# 모델 호출
response = model.generate_content(full_prompt)

# %%
print(response.text)
# Out:
# The answer is True.

# %% [markdown]
# # **과제** :
#
# 아래 문제에서는 할루시네이션이 발생한다. (답은 10 apples가 나와야 한다.)

# %%
prompt = """
I went to the market and bought 10 apples. I gave 2 apples to the neighbor and 2 to the repairman.
I then went and bought 5 more apples and ate 1. How many apples did I remain with?
"""

# %%
model = genai.GenerativeModel('gemini-pro')
# 전체 프롬프트 생성 (instruction 포함)
response = model.generate_content(prompt)

# %%
print(response.text)
# Out:
# 12 apples.

# %% [markdown]
# ***할루시네이션이 발생한 위의 문제를 올바르게 풀게끔 프롬프트를 만들어보세요.***

# %%
instruction = "Please read the following passage and calculate the number of apples remaining. Provide a clear and concise answer."
prompt = """
I went to the market and bought 10 apples. I gave 2 apples to the neighbor and 2 to the repairman.
I then went and bought 5 more apples and ate 1. How many apples did I remain with?
"""

# %%
model = genai.GenerativeModel('gemini-pro')
# 전체 프롬프트 생성 (instruction 포함)
full_prompt = f"{instruction}\n{prompt}"
# 모델 호출
response = model.generate_content(full_prompt)

# %%
print(response.text)
# Out:
# 10
#
# Explanation:
# I started with 10 apples. I gave away 2 and ate 1, leaving me with 7 apples. I then bought 5 more apples, bringing my total to 12 apples. However, I ate 1 of those, leaving me with 11 apples. So, the answer is 11 apples remaining.
